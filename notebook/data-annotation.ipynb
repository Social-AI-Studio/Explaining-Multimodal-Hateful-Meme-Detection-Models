# %% [markdown]
# # 1. Importing Dataset

# %%
import os
import json
import pandas as pd

# %%
annotation_folder = "/opt/datasets/mmf/datasets/hateful_memes/defaults/annotations"
detect_folder = "/opt/datasets/mmf/datasets/hateful_memes/defaults/web_detect"

race_info_folder = "/opt/datasets/race_entity_info/hatefulmemes"

# %%
train_annotation_df = pd.read_json(os.path.join(detect_folder, "web_detect_train_samples.jsonl"), orient="records", lines=True)
train_labels_df = pd.read_json(os.path.join(annotation_folder, "fine_grained", "train.json"), orient="records", lines=True)

# %%
val_annotation_df = pd.read_json(os.path.join(detect_folder, "web_detect_dev.jsonl"), orient="records", lines=True)
val_labels_df = pd.read_json(os.path.join(annotation_folder, "fine_grained", "dev_seen.json"), orient="records", lines=True)

# %%
train_annotation_df['index'] = train_annotation_df['index'].astype(int)
val_annotation_df['index'] = val_annotation_df['index'].astype(int)

# %%
race_df = pd.read_json(os.path.join(race_info_folder, "box_annos.race.json"))

# %% [markdown]
# # 2. Combining Datasets

# %% [markdown]
# ## 2.1 Cleaning Labels

# %%
train_labels_df.head()
# Out:
#       id set_name            img  \
# 0  42953    train  img/42953.png
# 1  23058    train  img/23058.png
# 2  13894    train  img/13894.png
# 3  37408    train  img/37408.png
# 4  82403    train  img/82403.png
#
#                                                 text      gold_hate  \
# 0   its their character not their color that matters  [not_hateful]
# 1  don't be afraid to love again everyone is not ...  [not_hateful]
# 2                           putting bows on your pet  [not_hateful]
# 3  i love everything and everybody! except for sq...  [not_hateful]
# 4  everybody loves chocolate chip cookies, even h...  [not_hateful]
#
#       gold_pc     gold_attack    pc attack
# 0  [pc_empty]  [attack_empty]  None   None
# 1  [pc_empty]  [attack_empty]  None   None
# 2  [pc_empty]  [attack_empty]  None   None
# 3  [pc_empty]  [attack_empty]  None   None
# 4  [pc_empty]  [attack_empty]  None   None

# %%
train_labels_df['gold_hate'] = train_labels_df['gold_hate'].apply(lambda x: x[0])
train_labels_df.drop(columns=['pc', 'attack', 'set_name'], inplace=True)
train_labels_df.set_index('id', inplace=True)

val_labels_df['gold_hate'] = val_labels_df['gold_hate'].apply(lambda x: x[0])
val_labels_df.drop(columns=['pc', 'attack', 'set_name'], inplace=True)
val_labels_df.set_index('id', inplace=True)

# %%
train_labels_df.head()
# Out:
#                  img                                               text  \
# id
# 42953  img/42953.png   its their character not their color that matters
# 23058  img/23058.png  don't be afraid to love again everyone is not ...
# 13894  img/13894.png                           putting bows on your pet
# 37408  img/37408.png  i love everything and everybody! except for sq...
# 82403  img/82403.png  everybody loves chocolate chip cookies, even h...
#
#          gold_hate     gold_pc     gold_attack
# id
# 42953  not_hateful  [pc_empty]  [attack_empty]
# 23058  not_hateful  [pc_empty]  [attack_empty]
# 13894  not_hateful  [pc_empty]  [attack_empty]
# 37408  not_hateful  [pc_empty]  [attack_empty]
# 82403  not_hateful  [pc_empty]  [attack_empty]

# %%
print(train_labels_df.shape, val_labels_df.shape)
# Out:
# (8500, 5) (500, 5)

# %%
train_labels_df = train_labels_df[train_labels_df.index.isin(train_annotation_df['index'].unique())]
val_labels_df = val_labels_df[val_labels_df.index.isin(val_annotation_df['index'].unique())]

# %%
print(train_labels_df.shape, val_labels_df.shape)
# Out:
# (500, 5) (500, 5)

# %% [markdown]
# ## 2.2 Cleaning Annotation

# %%
train_annotation_df.head()
# Out:
#    index                     best_guess_labels  \
# 0  52743                        [moteur turbo]
# 1  37895                                 [car]
# 2  29703                             [eyewear]
# 3  75294  [alexandria ocasio cortez in action]
# 4  60451                       [photo caption]
#
#                                         full_matches partial_matches  \
# 0  [https://media.istockphoto.com/photos/performa...              []
# 1  [https://media.gettyimages.com/photos/women-fr...              []
# 2                                                 []              []
# 3  [https://i.insider.com/5c068d3d0e2bf860a654087...              []
# 4                                                 []              []
#
#                                             entities  \
# 0  [{'score': 0.8115000129000001, 'description': ...
# 1  [{'score': 0.7287999988, 'description': 'Motor...
# 2  [{'score': 0.5329114199, 'description': 'Produ...
# 3  [{'score': 14.998500824, 'description': 'Alexa...
# 4  [{'score': 0.4034947753, 'description': 'Produ...
#
#                                     visually_similar
# 0  [http://www.fiches-auto.fr/sdoms/shiatsu/uploa...
# 1  [https://melbournevipcashforcars.com.au/wp-con...
# 2  [https://l450v.alamy.com/450v/wa9bt2/croquet-i...
# 3  [https://odaction.com/wp-content/uploads/2019/...
# 4  [https://i.kym-cdn.com/photos/images/original/...

# %%
val_annotation_df.head()
# Out:
#    index         best_guess_labels  \
# 0   8291        [transgender kids]
# 1  46971                 [glasses]
# 2   3745                    [desk]
# 3  83745                        []
# 4  80243  [monochrome photography]
#
#                                         full_matches partial_matches  \
# 0  [https://i0.wp.com/post.healthline.com/wp-cont...              []
# 1  [https://media.istockphoto.com/photos/end-of-t...              []
# 2                                                 []              []
# 3  [https://www.history.com/.image/ar_4:3%2Cc_fil...              []
# 4  [https://media.gettyimages.com/photos/this-pic...              []
#
#                                             entities  \
# 0  [{'score': 0.5564999580000001, 'description': ...
# 1  [{'score': 1.0561499596, 'description': 'Fried...
# 2  [{'score': 0.5328160524000001, 'description': ...
# 3  [{'score': 0.7148000002, 'description': ''}, {...
# 4  [{'score': 0.7729064226, 'description': 'Black...
#
#                                     visually_similar
# 0  [https://i.insider.com/5ddc180079d7570dad3b564...
# 1  [https://amc-theatres-res.cloudinary.com/image...
# 2  [http://static-15.sinclairstoryline.com/resour...
# 3  [https://pbs.twimg.com/media/E2PUeD8XoBIprYI.j...
# 4  [https://landmarksdekalbal.org/wp-content/uplo...

# %%
train_annotation_df[train_annotation_df['best_guess_labels'].apply(len) > 1]
# Out:
# Empty DataFrame
# Columns: [index, best_guess_labels, full_matches, partial_matches, entities, visually_similar]
# Index: []

# %%
val_annotation_df[val_annotation_df['partial_matches'].apply(len) > 0]
# Out:
# Empty DataFrame
# Columns: [index, best_guess_labels, full_matches, partial_matches, entities, visually_similar]
# Index: []

# %%
val_annotation_df[val_annotation_df['best_guess_labels'].apply(len) > 1]
# Out:
# Empty DataFrame
# Columns: [index, best_guess_labels, full_matches, partial_matches, entities, visually_similar]
# Index: []

# %%
train_annotation_df['entities'] = train_annotation_df['entities'].apply(lambda entities: [x['description'] for x in entities])
train_annotation_df['best_guess_labels'] = train_annotation_df['best_guess_labels'].apply(lambda x: x[0])

val_annotation_df['entities'] = val_annotation_df['entities'].apply(lambda entities: [x['description'] for x in entities])
val_annotation_df['best_guess_labels'] = val_annotation_df['best_guess_labels'].apply(lambda x: x[0])

train_annotation_df.drop(columns=["full_matches", "partial_matches", "visually_similar"], inplace=True)
val_annotation_df.drop(columns=["full_matches", "partial_matches", "visually_similar"], inplace=True)

# %%
train_annotation_df.set_index("index", inplace=True)
val_annotation_df.set_index("index", inplace=True)

# %%
train_annotation_df.head()
# Out:
#                         best_guess_labels  \
# index
# 52743                        moteur turbo
# 37895                                 car
# 29703                             eyewear
# 75294  alexandria ocasio cortez in action
# 60451                       photo caption
#
#                                                 entities
# index
# 52743  [Car, Engine, Dodge Durango, Engine Oil, Turbo...
# 37895  [Motorcycle, , Harley-Davidson, Daytona Beach ...
# 29703  [Product design, Brand, Product, Smiley, Line,...
# 75294  [Alexandria Ocasio-Cortez, Politics, 2019 Wome...
# 60451                           [Product, Photo caption]

# %% [markdown]
# ## 2.3 Clean Race

# %%
race_df.head()
# Out:
#     img_name                                    boxes_and_score
# 0  01235.png  [{'ymin': 0.268042504787445, 'xmin': 0.3950905...
# 1  01236.png  [{'ymin': 0.655592083930969, 'xmin': 0.1557954...
# 2  01243.png  [{'ymin': 0.22486409544944702, 'xmin': 0.21732...
# 3  01245.png  [{'ymin': 0.276416897773742, 'xmin': 0.5804585...
# 4  01247.png  [{'ymin': 0.161682158708572, 'xmin': 0.2477303...

# %%
race_df['img_name'] = race_df['img_name'].apply(lambda x: int(x.split('.')[0]))

race_df['gender'] = race_df['boxes_and_score'].apply(lambda row: [x['gender'] for x in row if x['gender'] != None])
race_df['race'] = race_df['boxes_and_score'].apply(lambda row: [x['race'] for x in row if x['race'] != None])

# %%
race_df.drop(columns=['boxes_and_score'], inplace=True)
race_df.set_index('img_name', inplace=True)
race_df.head()
# Out:
#                             gender  \
# img_name
# 1235                        [Male]
# 1236      [Male, Male, Male, Male]
# 1243                            []
# 1245                  [Male, Male]
# 1247                        [Male]
#
#                                                        race
# img_name
# 1235                                       [Middle Eastern]
# 1236      [Indian, Latino_Hispanic, Latino_Hispanic, Lat...
# 1243                                                     []
# 1245                                         [White, White]
# 1247                                                [White]

# %% [markdown]
# ## 2.4 Combining Dataframes

# %%
train_combined_df = pd.merge(train_labels_df, train_annotation_df, left_index=True, right_index=True)
train_combined_df = pd.merge(train_combined_df, race_df, left_index=True, right_index=True)
train_combined_df.sort_index(inplace=True)
train_combined_df.head()
# Out:
#                 img                                               text  \
# 1395  img/01395.png  i just found out mexican babies come out just ...
# 1487  img/01487.png                    when you forget you're retarded
# 1497  img/01497.png  now back to the married islamic classic.. to c...
# 1579  img/01579.png  muslim figure: "we must have pork-free menus o...
# 2158  img/02158.png  i like my women like i like my chickens held i...
#
#      gold_hate        gold_pc                        gold_attack  \
# 1395   hateful  [nationality]                     [dehumanizing]
# 1487   hateful   [disability]                      [inferiority]
# 1497   hateful     [religion]                     [dehumanizing]
# 1579   hateful     [religion]                        [exclusion]
# 2158   hateful          [sex]  [inciting_violence, dehumanizing]
#
#              best_guess_labels  \
# 1395  pregnancy painful labour
# 1487                    sirius
# 1497             photo caption
# 1579         با حجاب در آمریکا
# 2158                     fauna
#
#                                                entities  \
# 1395  [Childbirth, Pregnancy, Pain, Pain management ...
# 1487                                     [Poster, Font]
# 1497  [, Nangalam, Getty Images, Image, Photo captio...
# 1579  [United States, , Islam in the United States, ...
# 2158  [Typhoid fever, Fowl, Birds, Barnevelder, Poli...
#
#                                                 gender  \
# 1395              [Female, Male, Male, Female, Female]
# 1487                                  [Female, Female]
# 1497                                [Male, Male, Male]
# 1579  [Female, Male, Female, Male, Male, Male, Female]
# 2158                                                []
#
#                                                    race
# 1395                [White, White, White, White, White]
# 1487                                     [White, White]
# 1497                            [Indian, White, Indian]
# 1579  [Latino_Hispanic, Black, White, Black, Black, ...
# 2158                                                 []

# %%
# Ensure that all records are kept
print(train_labels_df.shape, train_combined_df.shape)
# Out:
# (500, 5) (500, 9)

# %%
val_combined_df = pd.merge(val_labels_df, val_annotation_df, left_index=True, right_index=True)
val_combined_df = pd.merge(val_combined_df, race_df, left_index=True, right_index=True)
val_combined_df.sort_index(inplace=True)
val_combined_df.head()
# Out:
#                 img                                               text  \
# 1268  img/01268.png  father and daughter bonding time is the best l...
# 1456  img/01456.png            they see them rollin..... they hating..
# 1726  img/01726.png        a real man loads the dishwasher every night
# 1742  img/01742.png  in just one hour from now i'll only have 4 hou...
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
#
#         gold_hate      gold_pc          gold_attack       best_guess_labels  \
# 1268  not_hateful   [pc_empty]       [attack_empty]           photo caption
# 1456      hateful   [religion]            [mocking]                  poster
# 1726      hateful        [sex]       [dehumanizing]  خودکشی مجری رادیو مشهد
# 1742  not_hateful   [pc_empty]       [attack_empty]                Computer
# 1765      hateful  [race, sex]  [inciting_violence]                  poster
#
#                                                entities  \
# 1268  [Human behavior, Photo caption, Product, Font,...
# 1456  [Heinrich Himmler, La maldad: raíces antropoló...
# 1726  [Health, Human sexual activity, Sleep, Reprodu...
# 1742  [Computer security, Computer, Computer Monitor...
# 1765  [Stock photography, , Getty Images, Image, Pho...
#
#                                                  gender  \
# 1268                                 [Male, Male, Male]
# 1456  [Male, Male, Male, Female, Male, Female, Male,...
# 1726                                                 []
# 1742                                             [Male]
# 1765                                       [Male, Male]
#
#                                                    race
# 1268                              [White, White, White]
# 1456  [White, White, White, Middle Eastern, White, W...
# 1726                                                 []
# 1742                                       [East Asian]
# 1765                                     [Black, Black]

# %%
# Ensure that all records are kept
print(val_labels_df.shape, val_combined_df.shape)
# Out:
# (500, 5) (500, 9)

# %% [markdown]
# ## 2.6 Saving Combined DataFrames

# %%
train_combined_df.to_csv(os.path.join("..","..","annotations", "train_sampled_combined.csv"))
val_combined_df.to_csv(os.path.join("..","..","annotations", "dev_sampled_combined.csv"))

# %% [markdown]
# ## 2.7 Adding Manual Labels

# %%
val_labels = ",,female,,black&LGBT,middle east&muslim&LGBT,middle east,,,,,,black,,black,female,black,female,,,,,,,black,,,,,female,,,,white,,,,muslim&LGBT,male,,,LGBT,,,,,,???&???,black,female,LGBT,black,,,,,,,,,middle east (iraqi),,black,hispanic/latino,,,,LGBT,LGBT,female,,female,,,female&intellectual disability,???&???,,,,,islam&middle east,,,,,,,,,,black,,,,,white,,,white,,,,,,,white or black,,black,,middle east&islam,,,,,,,female,,,,,black,male,,,,,,,,white,???&male,,,,LGBT,,,,judaism&middle east,,,,,female&leg impairment,,LGBT,,,white,,black,,,,,black,,LGBT,,,black,,,,,,,,female,black,,,,,,female,,,,,,female,,,,LGBT,,,,,,LGBT,,,,female,,,black,,,,,,,,LGBT,black,,,LGBT,,,,???,,,LGBT,female,,,,,,,???,,,,female,,,,,,female&asia,,,,,,,,black,,hispanic/latino (mexican),,female,black,black&???,,,,,,,,,female,,,black,,,black,,,,,,white,,,,,female,,,,,,,white,hispanic/latino,black,,,,,,,,,chinese&east asian,,,,,,,,,,black,,,,,,,,,black,,,german&judaism (???),,,black,,,,,,,,,,,,,???,,,,,,,LGBT,white&male,,,black,,female,white,,black&islam,,,female&leg impairment,,black,,,,,,,,,black,,black,,female,,,,,LGBT&leg impairment,,,,female,,,,,,female,,,,,,,,,,,,black,black,,,,,???,,,,,female,,,,middle east,,middle east&islam,,???,,,,,,,,,christian&male,,female,,,black,,middle east (iraqi),,,,,,,,,hispanic/latino,black&down syndrome,black,,,female,,,,,,,,,,female,,black&islam,,female,,black&islam,,,,black,,,,,female,,,,black&female,,,,,,,,,,LGBT,female,,white,black,,,,white,,,,,,,,,black,"
val_difficulties = ",,,,context_medium,context_difficult,text_easy,,,,,,context_medium,,context_medium,,context_medium,,,,,,,,text_easy,,,,,,,,,context_medium,,,,,,,,,,,,,,,context_medium,,,context_medium,,,,,,,,,text_easy&context_medium,,context_medium,context_medum,,,,,,,,,,,,,,,,,context_medium,,,,,,,,,,context_medium,,,,,context_medium,,,knowledge_hard,,,,,,,context_medium,,context_medium,,context_medium,,,,,,,,,,,,context_medium,,,,,,,,,context_medium& knowledge_hard,context_medium,,,,,,,,context_medium,,,,,,,,,,context_medium,,context_medium,,,,,context_medium,,,,,context_medium,,,,,,,,,context_medium,,,,,,,,,,,,,,,,,,,,,,,,,,,,,context_medium,,,,,,,,,context_medium,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,context_medium,,knowledge_hard,,,context_medium,text_easy,,,,,,,,,,,,context_medium,,,context_medium,,,,,,context_medium,,,,,,,,,,,,context_medium& knowledge_hard,context_medium& knowledge_hard,text_easy,,,,,,,,,text_easy,,,,,,,,,,context_medium,,,,,,,,,context_medium,,,,,,context_medium,,,,,,,,,,,,,,,,,,,,,,,,context_medium,,,text_easy,,context_medium,,,,,context_medium,,,,,,,,,context_medium,,context_medium,,,,,,,,,,,,,,,,,,,,,,,,,,,,,context_medium,context_medium,,,,,,,,,,,,,,knowledge_hard,,context_medium,,,,,,,,,,,,,,,,context_medium,,knowledge_hard,,,,,,,,,context_medium,context_medium,context_medium,,,,,,,,,,,,,,,context_medium,,,,context_medium,,,,context_medium,,,,,,,,,context_medium,,,,,,,,,,,,,context_medium,context_medium,,,,knowledge_hard,,,,,,,,,context_medium,"

train_labels = "mexico,intellectual disability,muslim,muslim,female,autism,dwarfism,black,muslim,black,illegal immigrant,down syndrome,down syndrome,illegal immigrant,autism or  intellectual disability or down syndrome,india,rheumatoid arithritis (inflammatory arthritis),black,black,LGBT,dwarfism,amyotrophic lateral sclerosis (motor disease),muslim,black,east asia,???,amyotrophic lateral sclerosis (motor disease),mexico,female,jews,muslim,muslim,jews (???),black,white,female,illegal immigrant,christianity,muslim,???,black,down syndrome,LGBT,conjoined twins,LGBT,LGBT,mexico,muslim or  jews,black,muslim,female,french,???,muslim,jews,black,???,LGBT,???,east asia (korea),intellectual disability,catholic christian,middle east (jews),conjoined twins,black,black,LGBT,down syndrome,american indian,romamians,muslim,mexico,muslim,muslim,amyotrophic lateral sclerosis (motor disease),limb impairment,hearing impairment,east asia (chinese),Parkinson's disease,LGBT,female,jews,refugee,intellectual disability,intellectual disability,limb impairment,mexico,mexico,limb impairment,stroke,mexico,LGBT,LGBT,muslim,middle east (arab),middle east (iraqi),muslim,limb impairment,muslim,muslim,israel,white,black,facial impairment,muslim,diabetes,???,white,down syndrome,black,muslim,down syndrome,rheumatoid arithritis,black,LGBT,jews,LGBT,muslim,muslim,muslim,LGBT,white,female,black,limb impairment,iraqi,muslim,intellectual disability,refugee,leprosy,female,muslim,mexico,LGBT,black,mexico,down syndrome,american,female,black,japan,jews (???),iraqi,refugee,LGBT,refugee,LGBT,limb impairment,Mislabeled,LGBT,jews (???),vision impairment,black,mexico,down syndrome,east asia (chinese),africa,american,muslim,muslim,mexico,black,limb impairment,muslim,??? (criminials),LGBT,muslim,black,conjoined twins,black,mexico,american indian,jews,muslim,rheumatoid arithritis,???,muslim,black,america,mexico,???,female,muslim,female,black,dwarfism,muslim,LGBT,cancer (leukemia) (cancer),???,??? (america0,mexico,mexico,muslim,autism,female,mexico,mexico,LGBT,??? (white),LGBT,japan,south korea,jews,muslim,LGBT,black,black,??? (muslim),??? (black),muslim,intellectual disability,black,female,africa,mexico,??? (muslim),muslim,autism,black,female,???,female,LGBT,japan,jews,jews,down syndrome,white,refugee,female,???,depression,mexico,jews,muslim,???,???,muslim,cancer (leukemia) (cancer),jews,refugee,refugee (middle east),stammering,jews,ptosis,???,africa,female,mexico,intellectual disability,illegal immigrant,female,LGBT,asia (chinese),jews,illegal immigrant,down syndrome,??? (israel),muslim,LGBT,female,handicap,???,LGBT,jews,female,female,black,black,LGBT,LGBT,autism,stroke,dyslexic,LGBT,mexico,black,white,dwarfism,black,rheumatoid arithritis,black,LGBT,mexico,muslim,female,muslim,female,limb impairment,LGBT,down syndrome,vision impairment,LGBT,muslim,black,jews,muslim,black,refugee,??? (muslim),??? (europe),black,jews,??? (India/africas),LGBT,jews,female,muslim,LGBT,LGBT,black,jews,LGBT,female,???,female,black,black,on the verge of dying,black,north korean,black,limb impairment,muslim,black,female,germans,female,LGBT,iraqi,LGBT,LGBT,muslim,???,limb impairment,black,epilepsy,??? (black),female,black,???,jews,down syndrome,muslim,female,??? (america),black,illegal immigrant,catholic christian,mexico,american,black,africa,???,LGBT,jews,black,paralysis,jews,epilepsy,down syndrome,muslim,africa,mexico,black,LGBT,canada,muslim,muslim,mexico,down syndrome,american,cancer,LGBT,jews,mexico,autism,iraqi,jews,intellectual disability,LGBT,female,???,intellectual disability,down syndrome,LGBT,muslim,LGBT,jews,refugee,down syndrome,mexico,refugee,???,muslim,??? (europes),paralysis,conjoined twins,black,LGBT,female,LGBT,german,vision impairment,???,epilepsy,middle east (arab),hearing impairment,muslim,black,black,white,intellectual disability,black,LGBT,black,africa,black,black,LGBT,vision impairment,muslim,jews,???,LGBT,muslim,LGBT,LGBT,female,black,white,intellectual disability,???,female,Mislabeled,???,female,iraqi,??? (white police),muslim,LGBT,mexico,LGBT,female,muslim,intellectual disability,american indian,LGBT,black,africa,black,muslim,catholic christian,muslim,LGBT,female,europe,LGBT,hearing impairment,muslim,female,white,???,female,muslim,limb impairment,???,american,female,illegal immigrant,dwarfism,muslim,muslim,german,black,black,intellectual disability,down syndrome,???,jews,europe,asian,LGBT,muslim,down syndrome,LGBT,black,muslim,middle east (african),hearing impairment,mexico,???,black,???,muslim,muslim,black,???,LGBT"
train_difficulties = ",,,,text_easy,,,context_medium,,context_medium,easy,,,hard,hard,,,context_medium& knowledge_hard,text_easy&context_medium,text_easy,,,,easy_text&knowledge_hard,knowledge_hard,,,,text_easy,,,,,knowledge_hard,,context_medium,easy,easy&hard,,,knowledge_hard,easy&hard,context_medium,,text_easy,text_easy,,,text_easy,,text_easy,,,,,text_easy,,text_easy,hard,knowledge_hard,,,text_easy,hard,text_easy,text_easy,text_easy,,easy_text& medium_context,,,,,,,,,easy_text,,text_easy,context_medium,,easy,,hard,,,,hard,,,text_easy,text_easy,,context_medium& knowledge_hard,,,,,,,text_image,text_image,,,,,context_medium,,context_medium&knowledge_hard,,,,context_medium& knowledge_hard,text_easy,,text_easy,,,,context_medium,text_easy,context_medium,text_easy,,,,,easy& hard,,context_medium,,,context_medium,knowledge_hard,,,easy,text_easy,text_easy,,,,easy,context_medium,hard,context_medium,,,context_medium,,,text_easy,hard,,context_medium& knowledge_hard,easy,,,,hard,text_easy,,,context_medium,text_easy&context_medium,,context_medium,,context_medium& knowledge_hard,,,,,,,,context_medium,,,hard,context_medium&knowledge_hard,,context_medium,text_easy,,,text_easy,easy,,hard,,,,,context_medium& knowledge_hard,,,text_easy,,text_easy,,,,,knowledge_hard,text_easy,text_easy,,,,,knowledge_hard,context_medium,,,,,,context_medium,text_easy?,,context_medium,context_medium,hard,,,,text_easy,easy,context_medium,,,,,,hard,,,easy,,easy,hard,,,hard,,,context_medium,,,easy,context_medium,text_easy,,,easy,,hard,,text_easy,text_easy&context_medium,easy,,text_easy,,text_easy,context_medium,text_easy& knowledge_hard,text_easy,text_easy?,text_easy,,,,text_easy,,text_easy,text_easy,,context_medium,,knowledge_hard,context_medium,,,context_medium,,context_medium,,knowledge_hard,,,text_easy,,context_medium,,,knowledge_hard,easy,,,text_easy,,easy&hard,text_easy,,context_medium,,context_medium,text_easy,context_medium,,text_easy,text_easy,,context_medium,text_easy,text_easy,easy,knowledge_hard,,text_easy,,,context_medium,context_medium,,context_medium,text_easy,,text_easy,knowledge_hard,,,,context_medium,,,text_easy,context_medium,,,,,text_easy,???,context_medium,easy,easy,,,context_medium,,,text_easy,,text_easy,,,,easy,,,,context_medium,text_easy,,,,,,easy&hard,hard,text_easy,,,,,,easy,text_easy,context_medium,,,,text_easy,,text_easy,,easy,,easy,easy,,,hard,,,context_medium& knowledge_hard,context_medium,text_easy,text_easy,,,,,text_easy,,,text_easy,context_medium,text_easy,,context_medium& knowledge_hard,context_medium,text_easy,easy,context_medium,text_easy,text_easy,,,,,context_medium,,text_easy,text_easy,text_easy,context_medium,text_easy,,,text_easy,,,text_easy,,,,text_easy,,text_easy,context_medium,,,text_easy,context_medium,context_medium,,text_easy,,easy,,text_easy,context_medium,,text_easy,,,text_easy,text_easy,,text_easy,,,,,text_easy,easy,,,,,context_medium,text_easy,,,,,,context_medium,text_easy,,medium,text_easy,knowledge_hard,,context_medium& knowledge_hard,,hard,,text_easy,,,,context_medium,,text_easy"

# %%
train_labels, val_labels = train_labels.split(','), val_labels.split(',')
val_difficulties, train_difficulties = val_difficulties.split(','), train_difficulties.split(',')

print(len(train_labels), len(val_labels))
print(len(train_difficulties), len(val_difficulties))
# Out:
# 500 500
# 500 500

# %%
train_combined_df['manual_label'] = train_labels
val_combined_df['manual_label'] = val_labels

train_combined_df['difficulty_level'] = train_difficulties
val_combined_df['difficulty_level'] = val_difficulties

# %%
train_combined_df['manual_label'] = train_combined_df['manual_label'].apply(lambda x: x.split('&'))
val_combined_df['manual_label'] = val_combined_df['manual_label'].apply(lambda x: x.split('&'))

# %%
train_combined_df.head()
# Out:
#                 img                                               text  \
# 1395  img/01395.png  i just found out mexican babies come out just ...
# 1487  img/01487.png                    when you forget you're retarded
# 1497  img/01497.png  now back to the married islamic classic.. to c...
# 1579  img/01579.png  muslim figure: "we must have pork-free menus o...
# 2158  img/02158.png  i like my women like i like my chickens held i...
#
#      gold_hate        gold_pc                        gold_attack  \
# 1395   hateful  [nationality]                     [dehumanizing]
# 1487   hateful   [disability]                      [inferiority]
# 1497   hateful     [religion]                     [dehumanizing]
# 1579   hateful     [religion]                        [exclusion]
# 2158   hateful          [sex]  [inciting_violence, dehumanizing]
#
#              best_guess_labels  \
# 1395  pregnancy painful labour
# 1487                    sirius
# 1497             photo caption
# 1579         با حجاب در آمریکا
# 2158                     fauna
#
#                                                entities  \
# 1395  [Childbirth, Pregnancy, Pain, Pain management ...
# 1487                                     [Poster, Font]
# 1497  [, Nangalam, Getty Images, Image, Photo captio...
# 1579  [United States, , Islam in the United States, ...
# 2158  [Typhoid fever, Fowl, Birds, Barnevelder, Poli...
#
#                                                 gender  \
# 1395              [Female, Male, Male, Female, Female]
# 1487                                  [Female, Female]
# 1497                                [Male, Male, Male]
# 1579  [Female, Male, Female, Male, Male, Male, Female]
# 2158                                                []
#
#                                                    race  \
# 1395                [White, White, White, White, White]
# 1487                                     [White, White]
# 1497                            [Indian, White, Indian]
# 1579  [Latino_Hispanic, Black, White, Black, Black, ...
# 2158                                                 []
#
#                    manual_label difficulty_level
# 1395                   [mexico]
# 1487  [intellectual disability]
# 1497                   [muslim]
# 1579                   [muslim]
# 2158                   [female]        text_easy

# %% [markdown]
# # 3. Cleaning Text

# %%
import contractions

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    sent = sent.replace('\"', '')
    sent = contractions.fix(sent)
    sent = sent.lower()

    word_tokens = word_tokenize(sent)
    
    filtered_sentence = [lemmatizer.lemmatize(word) for word in word_tokens]

    filtered_sentence = [
        "".join(c for c in token if c not in ("?", ".", ";", ":", "!"))
        for token in filtered_sentence
    ]
    
    return filtered_sentence

# %%
def get_specific_label(row, label):
    pos = row['gold_pc'].index(label)
    return row['manual_label'][pos]

# %%
val_combined_df.loc[83045]['best_guess_labels']
# Out:
# '117th congress women'

# %%
clean_text(val_combined_df.loc[83045]['best_guess_labels'])
# Out:
# ['117th', 'congress', 'woman']

# %%
train_combined_df['text_cleaned'] = train_combined_df['text'].apply(clean_text)
train_combined_df['best_guess_labels_cleaned'] = train_combined_df['best_guess_labels'].apply(clean_text)
train_combined_df['entities_cleaned'] = train_combined_df['entities'].apply(lambda x: clean_text(' '.join(x)))

# %%
val_combined_df['text_cleaned'] = val_combined_df['text'].apply(clean_text)
val_combined_df['best_guess_labels_cleaned'] = val_combined_df['best_guess_labels'].apply(clean_text)
val_combined_df['entities_cleaned'] = val_combined_df['entities'].apply(lambda x: clean_text(' '.join(x)))

# %% [markdown]
# # 4. Check Distribution

# %%
hateful_df = val_combined_df[val_combined_df['gold_hate'] == 'hateful']
hateful_df.head()
# Out:
#                 img                                               text  \
# 1456  img/01456.png            they see them rollin..... they hating..
# 1726  img/01726.png        a real man loads the dishwasher every night
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
# 1796  img/01796.png       life hack #23 how to get stoned with no weed
# 1925  img/01925.png      i am not racist i just don't like brown sugar
#
#      gold_hate                gold_pc          gold_attack  \
# 1456   hateful             [religion]            [mocking]
# 1726   hateful                  [sex]       [dehumanizing]
# 1765   hateful            [race, sex]  [inciting_violence]
# 1796   hateful  [race, religion, sex]  [inciting_violence]
# 1925   hateful                 [race]           [contempt]
#
#            best_guess_labels  \
# 1456                  poster
# 1726  خودکشی مجری رادیو مشهد
# 1765                  poster
# 1796              photograph
# 1925             Scholarship
#
#                                                entities  \
# 1456  [Heinrich Himmler, La maldad: raíces antropoló...
# 1726  [Health, Human sexual activity, Sleep, Reprodu...
# 1765  [Stock photography, , Getty Images, Image, Pho...
# 1796  [Photograph, Hug, Photo caption, Product, Frie...
# 1925  [Amelia Lost: The Life and Disappearance of Am...
#
#                                                  gender  \
# 1456  [Male, Male, Male, Female, Male, Female, Male,...
# 1726                                                 []
# 1765                                       [Male, Male]
# 1796           [Female, Female, Female, Female, Female]
# 1925                           [Female, Female, Female]
#
#                                                    race  \
# 1456  [White, White, White, Middle Eastern, White, W...
# 1726                                                 []
# 1765                                     [Black, Black]
# 1796  [Southeast Asian, Southeast Asian, Southeast A...
# 1925                           [Indian, Indian, Indian]
#
#                      manual_label   difficulty_level  \
# 1456                           []
# 1726                     [female]
# 1765                [black, LGBT]     context_medium
# 1796  [middle east, muslim, LGBT]  context_difficult
# 1925                [middle east]          text_easy
#
#                                            text_cleaned  \
# 1456        [they, see, them, rollin, , , they, hating]
# 1726  [a, real, man, load, the, dishwasher, every, n...
# 1765  [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796  [life, hack, #, 23, how, to, get, stoned, with...
# 1925  [i, am, not, racist, i, just, do, not, like, b...
#
#         best_guess_labels_cleaned  \
# 1456                     [poster]
# 1726  [خودکشی, مجری, رادیو, مشهد]
# 1765                     [poster]
# 1796                 [photograph]
# 1925                [scholarship]
#
#                                        entities_cleaned
# 1456  [heinrich, himmler, la, maldad, , raíces, antr...
# 1726  [health, human, sexual, activity, sleep, repro...
# 1765  [stock, photography, getty, image, image, phot...
# 1796  [photograph, hug, photo, caption, product, fri...
# 1925  [amelia, lost, , the, life, and, disappearance...

# %% [markdown]
# ## Sex Distribution

# %%
train_sex_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'sex' in x)]
train_sex_df.shape
# Out:
# (100, 14)

# %%
train_sex_df['manual_label'] = train_sex_df['manual_label'].apply(lambda x: x[0])
train_sex_df['manual_label'].value_counts()
# Out:
# <ipython-input-42-f64c3b505e80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['manual_label'] = train_sex_df['manual_label'].apply(lambda x: x[0])
# LGBT          59
# female        39
# Mislabeled     2
# Name: manual_label, dtype: int64

# %%
val_sex_df = hateful_df[hateful_df['gold_pc'].apply(lambda x: 'sex' in x)]
val_sex_df.shape
# Out:
# (56, 14)

# %%
val_sex_df['manual_label'] = val_sex_df.apply(lambda x: get_specific_label(x, 'sex'), axis=1)
val_sex_df['manual_label'].value_counts()
# Out:
# <ipython-input-44-127f4b74760c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['manual_label'] = val_sex_df.apply(lambda x: get_specific_label(x, 'sex'), axis=1)
# female    33
# LGBT      18
# male       5
# Name: manual_label, dtype: int64

# %% [markdown]
# ## 4.2 Race Distribution

# %%
train_race_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'race' in x)]
train_race_df.shape
# Out:
# (100, 14)

# %%
train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0])
train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
train_race_df['manual_label'].value_counts()
# Out:
# <ipython-input-46-11d57babfbca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0])
# <ipython-input-46-11d57babfbca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
# black              62
# ???                16
# white               9
# middle east         5
# east asia           4
# american indian     3
# asian               1
# Name: manual_label, dtype: int64

# %%
val_race_df = hateful_df[hateful_df['gold_pc'].apply(lambda x: 'race' in x)]
val_race_df.shape
# Out:
# (78, 14)

# %%
val_race_df['manual_label'] = val_race_df.apply(lambda x: get_specific_label(x, 'race'), axis=1)
val_race_df['manual_label'] = val_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
val_race_df['manual_label'].value_counts()
# Out:
# <ipython-input-48-1fd5f5b48bc9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['manual_label'] = val_race_df.apply(lambda x: get_specific_label(x, 'race'), axis=1)
# <ipython-input-48-1fd5f5b48bc9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['manual_label'] = val_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
# black              42
# white              11
# middle east         9
# ???                 8
# hispanic/latino     4
# white or black      1
# german              1
# asia                1
# east asian          1
# Name: manual_label, dtype: int64

# %% [markdown]
# ## 4.3 Religion Distribution

# %%
train_religion_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'religion' in x)]
train_religion_df.shape
# Out:
# (100, 14)

# %%
train_religion_df['manual_label'] = train_religion_df['manual_label'].apply(lambda x: x[0])
train_religion_df['manual_label'] = train_religion_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
train_religion_df['manual_label'].value_counts()
# Out:
# <ipython-input-50-ae6e7f1d88cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['manual_label'] = train_religion_df['manual_label'].apply(lambda x: x[0])
# <ipython-input-50-ae6e7f1d88cb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['manual_label'] = train_religion_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
# muslim                65
# jews                  28
# catholic christian     3
# ???                    2
# christianity           1
# muslim or  jews        1
# Name: manual_label, dtype: int64

# %% [markdown]
# ## 4.4 Nationality Distribution

# %%
train_nationality_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'nationality' in x)]
train_nationality_df.shape
# Out:
# (100, 14)

# %%
train_nationality_df['manual_label'] = train_nationality_df['manual_label'].apply(lambda x: x[0])
train_nationality_df['manual_label'] = train_nationality_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
train_nationality_df['manual_label'].value_counts()
# Out:
# <ipython-input-52-819376fac174>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_nationality_df['manual_label'] = train_nationality_df['manual_label'].apply(lambda x: x[0])
# <ipython-input-52-819376fac174>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_nationality_df['manual_label'] = train_nationality_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
# mexico               29
# ???                  19
# refugee              10
# africa                7
# illegal immigrant     7
# iraqi                 5
# american              5
# japan                 3
# europe                2
# german                2
# romamians             1
# india                 1
# north korean          1
# asia                  1
# french                1
# israel                1
# muslim                1
# canada                1
# america               1
# south korea           1
# germans               1
# Name: manual_label, dtype: int64

# %% [markdown]
# ## 4.5 Disability Distribution

# %%
train_disability_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'disability' in x)]
train_disability_df.shape
# Out:
# (100, 14)

# %%
train_disability_df['manual_label'] = train_disability_df['manual_label'].apply(lambda x: x[0])
train_disability_df['manual_label'] = train_disability_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
train_disability_df['manual_label'].value_counts()
# Out:
# <ipython-input-54-a9e3ed71b1c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_disability_df['manual_label'] = train_disability_df['manual_label'].apply(lambda x: x[0])
# <ipython-input-54-a9e3ed71b1c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_disability_df['manual_label'] = train_disability_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
# down syndrome                                          18
# intellectual disability                                13
# limb impairment                                        11
# ???                                                     8
# dwarfism                                                5
# autism                                                  5
# vision impairment                                       4
# rheumatoid arithritis                                   4
# hearing impairment                                      4
# conjoined twins                                         4
# amyotrophic lateral sclerosis                           3
# cancer                                                  3
# epilepsy                                                3
# stroke                                                  2
# paralysis                                               2
# handicap                                                1
# diabetes                                                1
# stammering                                              1
# autism or  intellectual disability or down syndrome     1
# on the verge of dying                                   1
# ptosis                                                  1
# facial impairment                                       1
# Parkinson's disease                                     1
# depression                                              1
# dyslexic                                                1
# leprosy                                                 1
# Name: manual_label, dtype: int64

# %% [markdown]
# # 3. Sex Analysis

# %%
import contractions
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

def lemmatize(sent):
    words = [lemmatizer.lemmatize(word) for word in sent.split()]
    return words

# %%
categories = (
    ("male", ("he", "man", "men", "boy", "male")),
    ("female", ("she", "woman", "woman", "girl", "feminist", "female", "dishwasher", "dish-washer", "sandwichmaker", "sandwich-maker", "sandwich")),
    ("LGBT", ("lgbt", "gay", 'bisexual', 'queer')) #LGBT
)

special_kws = [
    ("LGBT", "tran")
]

def assign_gender(sent):
    keywords, labels  = [], []
    for t in sent:
        for cat, kws in categories:
            if t in kws:
                keywords.append(t)
                labels.append(cat)
        
        for cat, special_kw in special_kws:
            if special_kw in t:
                keywords.append(t)
                labels.append(cat)
    
    return labels

def predict_gender(combined_cat):
    from collections import Counter
    
    if len(combined_cat) == 0:
        return "Unidentified"

    if "LGBT" in combined_cat:
        return "LGBT"
    
    counter = Counter(combined_cat)
    elements = counter.most_common(2)
    
    if len(elements) == 1 or elements[0][1] > elements[1][1]:
        return elements[0][0]
    
    return "Mixed"
        
        
#     return combined_series.apply(lambda x: "LGBT" if "LGBT" in x else max(set(lst), key=lst.count))

# %% [markdown]
# ## 3.1 Sex Analysis - Train

# %%
train_sex_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'sex' in x)]
train_sex_df.shape
# Out:
# (100, 14)

# %%
train_sex_df['manual_label'] = train_sex_df['manual_label'].apply(lambda x: x[0])
train_sex_df['manual_label'].value_counts()
# Out:
# <ipython-input-58-f64c3b505e80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['manual_label'] = train_sex_df['manual_label'].apply(lambda x: x[0])
# LGBT          59
# female        39
# Mislabeled     2
# Name: manual_label, dtype: int64

# %%
assign_gender(' '.join(train_sex_df.loc[9352]['entities']))
# Out:
# []

# %%
train_sex_df['text_cat'] = train_sex_df['text_cleaned'].apply(assign_gender)
train_sex_df['entities_cat'] = train_sex_df['entities_cleaned'].apply(assign_gender)
train_sex_df['best_guess_cat'] = train_sex_df['best_guess_labels_cleaned'].apply(assign_gender)

train_sex_df['combined_cat'] = train_sex_df['text_cat'] + train_sex_df['entities_cat'] + train_sex_df['best_guess_cat']
# Out:
# <ipython-input-60-e4691f363f3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['text_cat'] = train_sex_df['text_cleaned'].apply(assign_gender)
# <ipython-input-60-e4691f363f3b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['entities_cat'] = train_sex_df['entities_cleaned'].apply(assign_gender)
# <ipython-input-60-e4691f363f3b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['best_guess_cat'] = train_sex_df['best_guess_labels_cleaned'].apply(assign_gender)
# <ipython-input-60-e4691f363f3b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['combined_cat'] = train_sex_df['text_cat'] + train_sex_df['entities_cat'] + train_sex_df['best_guess_cat']

# %%
train_sex_df['pred_label'] = train_sex_df['combined_cat'].apply(predict_gender)
# train_sex_df.drop(columns=['text_cat', 'entities_cat', 'best_guess_cat', 'gender', 'race'], inplace=True)
train_sex_df.head()
# Out:
# <ipython-input-61-ca435d5bdc18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sex_df['pred_label'] = train_sex_df['combined_cat'].apply(predict_gender)
#                 img                                               text  \
# 2158  img/02158.png  i like my women like i like my chickens held i...
# 3794  img/03794.png                tranny jesus died for your eyebrows
# 6482  img/06482.png  i dont always make sandwiches because im not a...
# 8275  img/08275.png  the pimp hand strong enough for man but made f...
# 9352  img/09352.png                          they will soon be extinct
#
#      gold_hate gold_pc                        gold_attack best_guess_labels  \
# 2158   hateful   [sex]  [inciting_violence, dehumanizing]             fauna
# 3794   hateful   [sex]                            [slurs]         community
# 6482   hateful   [sex]                     [dehumanizing]     photo caption
# 8275   hateful   [sex]                [inciting_violence]        friendship
# 9352   hateful   [sex]  [inciting_violence, dehumanizing]       pride month
#
#                                                entities  \
# 2158  [Typhoid fever, Fowl, Birds, Barnevelder, Poli...
# 3794  [Festival M., Community, Festival, Recreation,...
# 6482  [, Photo caption, Illustration, Portugal, Heal...
# 8275  [Stock photography, , Getty Images, Photo capt...
# 9352  [Gay pride, LGBT community, Queer, Rainbow fla...
#
#                                         gender  \
# 2158                                        []
# 3794          [Female, Male, Male, Male, Male]
# 6482                        [Male, Male, Male]
# 8275                    [Male, Female, Female]
# 9352  [Female, Female, Female, Female, Female]
#
#                                                    race manual_label  \
# 2158                                                 []       female
# 3794  [Black, Middle Eastern, White, White, Middle E...         LGBT
# 6482   [Middle Eastern, Middle Eastern, Middle Eastern]       female
# 8275          [White, Latino_Hispanic, Latino_Hispanic]       female
# 9352                [White, White, White, White, White]         LGBT
#
#      difficulty_level                                       text_cleaned  \
# 2158        text_easy  [i, like, my, woman, like, i, like, my, chicke...
# 3794        text_easy          [tranny, jesus, died, for, your, eyebrow]
# 6482        text_easy  [i, do, not, always, make, sandwich, because, ...
# 8275   context_medium  [the, pimp, hand, strong, enough, for, man, bu...
# 9352   context_medium                    [they, will, soon, be, extinct]
#
#      best_guess_labels_cleaned  \
# 2158                   [fauna]
# 3794               [community]
# 6482          [photo, caption]
# 8275              [friendship]
# 9352            [pride, month]
#
#                                        entities_cleaned          text_cat  \
# 2158  [typhoid, fever, fowl, bird, barnevelder, poli...          [female]
# 3794  [festival, m, community, festival, recreation,...            [LGBT]
# 6482  [photo, caption, illustration, portugal, healt...  [female, female]
# 8275  [stock, photography, getty, image, photo, capt...            [male]
# 9352  [gay, pride, lgbt, community, queer, rainbow, ...                []
#
#                               entities_cat best_guess_cat  \
# 2158                                    []             []
# 3794                                [LGBT]             []
# 6482                                [male]             []
# 8275                              [female]             []
# 9352  [LGBT, LGBT, LGBT, LGBT, LGBT, LGBT]             []
#
#                               combined_cat pred_label
# 2158                              [female]     female
# 3794                          [LGBT, LGBT]       LGBT
# 6482                [female, female, male]     female
# 8275                        [male, female]      Mixed
# 9352  [LGBT, LGBT, LGBT, LGBT, LGBT, LGBT]       LGBT

# %%
print(train_sex_df[train_sex_df['combined_cat'].apply(len) != 0].shape)
print(train_sex_df[train_sex_df['combined_cat'].apply(len) == 0].shape)
# Out:
# (79, 19)
# (21, 19)

# %%
print(train_sex_df[train_sex_df['pred_label'] == train_sex_df['manual_label']].shape)
print(train_sex_df[train_sex_df['pred_label'] != train_sex_df['manual_label']].shape)
# Out:
# (73, 19)
# (27, 19)

# %%
mislabel_df = train_sex_df[(train_sex_df['pred_label'] != train_sex_df['manual_label']) & (train_sex_df['pred_label'] != 'Unidentified')]
print(mislabel_df.shape)
mislabel_df
# Out:
# (6, 19)
#                  img                                               text  \
# 8275   img/08275.png  the pimp hand strong enough for man but made f...
# 38271  img/38271.png  non-binary genders are real there are more tha...
# 52743  img/52743.png       like a hot ls swapped rx-7 girl with a penis
# 58631  img/58631.png  the same people that hate trump think this is ...
# 90723  img/90723.png              every man needs a decent coffee maker
# 92148  img/92148.png  once a year, women go completely crazy for abo...
#
#       gold_hate gold_pc          gold_attack            best_guess_labels  \
# 8275    hateful   [sex]  [inciting_violence]                   friendship
# 38271   hateful   [sex]       [dehumanizing]                   grumpy cat
# 52743   hateful   [sex]       [dehumanizing]                 moteur turbo
# 58631   hateful   [sex]       [dehumanizing]     caitlyn jenner net worth
# 90723   hateful   [sex]       [dehumanizing]  Ansmann Aes 1 Zero Watt One
# 92148   hateful   [sex]        [inferiority]         streetball young boy
#
#                                                 entities  \
# 8275   [Stock photography, , Getty Images, Photo capt...
# 38271  [Grumpy Cat, Persian cat, Grumpy Cat, Dog, Kit...
# 52743  [Car, Engine, Dodge Durango, Engine Oil, Turbo...
# 58631  [Celebrity, Kardashian Family, , Television pr...
# 90723  [Ansmann Aes 1 Zero Watt One, Ansmann időzítő ...
# 92148  [Infant, Parent, Parenting, Creative Care Chil...
#
#                        gender                                       race  \
# 8275   [Male, Female, Female]  [White, Latino_Hispanic, Latino_Hispanic]
# 38271                      []                                         []
# 52743                      []                                         []
# 58631        [Female, Female]                             [White, White]
# 90723        [Female, Female]                             [White, White]
# 92148  [Male, Female, Female]   [Indian, Middle Eastern, Middle Eastern]
#
#       manual_label difficulty_level  \
# 8275        female   context_medium
# 38271         LGBT        text_easy
# 52743         LGBT        text_easy
# 58631         LGBT   knowledge_hard
# 90723       female   context_medium
# 92148       female        text_easy
#
#                                             text_cleaned  \
# 8275   [the, pimp, hand, strong, enough, for, man, bu...
# 38271  [non-binary, gender, are, real, there, are, mo...
# 52743  [like, a, hot, l, swapped, rx-7, girl, with, a...
# 58631  [the, same, people, that, hate, trump, think, ...
# 90723       [every, man, need, a, decent, coffee, maker]
# 92148  [once, a, year, ,, woman, go, completely, craz...
#
#                 best_guess_labels_cleaned  \
# 8275                         [friendship]
# 38271                       [grumpy, cat]
# 52743                     [moteur, turbo]
# 58631       [caitlyn, jenner, net, worth]
# 90723  [ansmann, aes, 1, zero, watt, one]
# 92148            [streetball, young, boy]
#
#                                         entities_cleaned  text_cat  \
# 8275   [stock, photography, getty, image, photo, capt...    [male]
# 38271  [grumpy, cat, persian, cat, grumpy, cat, dog, ...        []
# 52743  [car, engine, dodge, durango, engine, oil, tur...  [female]
# 58631  [celebrity, kardashian, family, television, pr...  [female]
# 90723  [ansmann, aes, 1, zero, watt, one, ansmann, id...    [male]
# 92148  [infant, parent, parenting, creative, care, ch...  [female]
#
#       entities_cat best_guess_cat    combined_cat pred_label
# 8275      [female]             []  [male, female]      Mixed
# 38271     [female]             []        [female]     female
# 52743           []             []        [female]     female
# 58631           []             []        [female]     female
# 90723           []             []          [male]       male
# 92148           []         [male]  [female, male]      Mixed

# %%
unlabel_df = train_sex_df[(train_sex_df['pred_label'] != train_sex_df['manual_label']) & (train_sex_df['pred_label'] == 'Unidentified')]
print(unlabel_df.shape)
unlabel_df.head()
# Out:
# (21, 19)
#                  img                                               text  \
# 10328  img/10328.png  how dikes look when they're in line paying for...
# 13620  img/13620.png  when you get shot in the groin by a rubber bul...
# 17236  img/17236.png  this just in caitlyn jenner claims bruce fondl...
# 17326  img/17326.png         what the neighbors see what my father sees
# 25847  img/25847.png  they should not be allowed to have kids you ma...
#
#       gold_hate gold_pc            gold_attack  \
# 10328   hateful   [sex]                [slurs]
# 13620   hateful   [sex]    [inciting_violence]
# 17236   hateful   [sex]          [inferiority]
# 17326   hateful   [sex]    [inciting_violence]
# 25847   hateful   [sex]  [contempt, exclusion]
#
#                        best_guess_labels  \
# 10328                      photo caption
# 13620                      photo caption
# 17236                             poster
# 17326                         photograph
# 25847  mi sono innamorata di una ragazza
#
#                                                 entities  \
# 10328  [Image, Stock photography, Photograph, Getty I...
# 13620                        [Photo caption, Font, Dude]
# 17236                            [Poster, Photo caption]
# 17326  [Stock photography, , Image, , Getty Images, P...
# 25847  [Friendship, Lesbiaeth, Kiss, Multiracial peop...
#
#                                          gender  \
# 10328  [Female, Female, Female, Female, Female]
# 13620                              [Male, Male]
# 17236                      [Female, Male, Male]
# 17326          [Female, Female, Female, Female]
# 25847                  [Female, Female, Female]
#
#                                                     race manual_label  \
# 10328  [Latino_Hispanic, White, White, Latino_Hispani...         LGBT
# 13620                                     [Black, Black]         LGBT
# 17236                              [White, White, White]         LGBT
# 17326                       [White, White, White, White]       female
# 25847                              [White, White, White]         LGBT
#
#       difficulty_level                                       text_cleaned  \
# 10328        text_easy  [how, dike, look, when, they, are, in, line, p...
# 13620        text_easy  [when, you, get, shot, in, the, groin, by, a, ...
# 17236        text_easy  [this, just, in, caitlyn, jenner, claim, bruce...
# 17326   context_medium  [what, the, neighbor, see, what, my, father, see]
# 25847   context_medium  [they, should, not, be, allowed, to, have, kid...
#
#                       best_guess_labels_cleaned  \
# 10328                          [photo, caption]
# 13620                          [photo, caption]
# 17236                                  [poster]
# 17326                              [photograph]
# 25847  [mi, sono, innamorata, di, una, ragazza]
#
#                                         entities_cleaned text_cat  \
# 10328  [image, stock, photography, photograph, getty,...       []
# 13620                       [photo, caption, font, dude]       []
# 17236                           [poster, photo, caption]       []
# 17326  [stock, photography, image, getty, image, phot...       []
# 25847  [friendship, lesbiaeth, kiss, multiracial, peo...       []
#
#       entities_cat best_guess_cat combined_cat    pred_label
# 10328           []             []           []  Unidentified
# 13620           []             []           []  Unidentified
# 17236           []             []           []  Unidentified
# 17326           []             []           []  Unidentified
# 25847           []             []           []  Unidentified

# %% [markdown]
# # 3.2 Sex Analysis - Validation

# %%
val_sex_df = hateful_df[hateful_df['gold_pc'].apply(lambda x: 'sex' in x)]
val_sex_df.shape
# Out:
# (56, 14)

# %%
val_sex_df.loc[5938]
# Out:
# img                                                              img/05938.png
# text                             in the muslim world all gay men are well hung
# gold_hate                                                              hateful
# gold_pc                                                        [religion, sex]
# gold_attack                                  [inciting_violence, dehumanizing]
# best_guess_labels                                                photo caption
# entities                     [Photograph, Image, Stock photography, iStock,...
# gender                                                      [Male, Male, Male]
# race                                                     [White, White, White]
# manual_label                                                    [muslim, LGBT]
# difficulty_level
# text_cleaned                 [in, the, muslim, world, all, gay, men, are, w...
# best_guess_labels_cleaned                                     [photo, caption]
# entities_cleaned             [photograph, image, stock, photography, istock...
# Name: 5938, dtype: object

# %%
val_sex_df['manual_label'] = val_sex_df.apply(lambda x: get_specific_label(x, 'sex'), axis=1)
# Out:
# <ipython-input-68-b77bfcba16b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['manual_label'] = val_sex_df.apply(lambda x: get_specific_label(x, 'sex'), axis=1)

# %%
val_sex_df['manual_label'].value_counts()
# Out:
# female    33
# LGBT      18
# male       5
# Name: manual_label, dtype: int64

# %%
val_sex_df.head()
# Out:
#                 img                                               text  \
# 1726  img/01726.png        a real man loads the dishwasher every night
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
# 1796  img/01796.png       life hack #23 how to get stoned with no weed
# 2634  img/02634.png  and just like that... this sandwich maker doub...
# 3197  img/03197.png  i'm no bird expert but i'm guessing it's 4 fem...
#
#      gold_hate                gold_pc          gold_attack  \
# 1726   hateful                  [sex]       [dehumanizing]
# 1765   hateful            [race, sex]  [inciting_violence]
# 1796   hateful  [race, religion, sex]  [inciting_violence]
# 2634   hateful                  [sex]       [dehumanizing]
# 3197   hateful                  [sex]       [dehumanizing]
#
#            best_guess_labels  \
# 1726  خودکشی مجری رادیو مشهد
# 1765                  poster
# 1796              photograph
# 2634                   grass
# 3197                   fauna
#
#                                                entities  \
# 1726  [Health, Human sexual activity, Sleep, Reprodu...
# 1765  [Stock photography, , Getty Images, Image, Pho...
# 1796  [Photograph, Hug, Photo caption, Product, Frie...
# 2634  [Stock photography, Getty Images, , Photograph...
# 3197  [Pacific swallow, Birds, Barn swallow, Stock p...
#
#                                         gender  \
# 1726                                        []
# 1765                              [Male, Male]
# 1796  [Female, Female, Female, Female, Female]
# 2634          [Female, Female, Female, Female]
# 3197                                        []
#
#                                                    race manual_label  \
# 1726                                                 []       female
# 1765                                     [Black, Black]         LGBT
# 1796  [Southeast Asian, Southeast Asian, Southeast A...         LGBT
# 2634   [East Asian, East Asian, East Asian, East Asian]       female
# 3197                                                 []       female
#
#        difficulty_level                                       text_cleaned  \
# 1726                     [a, real, man, load, the, dishwasher, every, n...
# 1765     context_medium  [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796  context_difficult  [life, hack, #, 23, how, to, get, stoned, with...
# 2634                     [and, just, like, that, , this, sandwich, make...
# 3197                     [i, am, no, bird, expert, but, i, am, guessing...
#
#         best_guess_labels_cleaned  \
# 1726  [خودکشی, مجری, رادیو, مشهد]
# 1765                     [poster]
# 1796                 [photograph]
# 2634                      [grass]
# 3197                      [fauna]
#
#                                        entities_cleaned
# 1726  [health, human, sexual, activity, sleep, repro...
# 1765  [stock, photography, getty, image, image, phot...
# 1796  [photograph, hug, photo, caption, product, fri...
# 2634  [stock, photography, getty, image, photograph,...
# 3197  [pacific, swallow, bird, barn, swallow, stock,...

# %%
val_sex_df['text_cat'] = val_sex_df['text_cleaned'].apply(assign_gender)
val_sex_df['entities_cat'] = val_sex_df['entities_cleaned'].apply(assign_gender)
val_sex_df['best_guess_cat'] = val_sex_df['best_guess_labels'].apply(assign_gender)

val_sex_df['combined_cat'] = val_sex_df['text_cat'] + val_sex_df['entities_cat'] + val_sex_df['best_guess_cat']
# Out:
# <ipython-input-71-2562d00d73fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['text_cat'] = val_sex_df['text_cleaned'].apply(assign_gender)
# <ipython-input-71-2562d00d73fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['entities_cat'] = val_sex_df['entities_cleaned'].apply(assign_gender)
# <ipython-input-71-2562d00d73fa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['best_guess_cat'] = val_sex_df['best_guess_labels'].apply(assign_gender)
# <ipython-input-71-2562d00d73fa>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['combined_cat'] = val_sex_df['text_cat'] + val_sex_df['entities_cat'] + val_sex_df['best_guess_cat']

# %%
val_sex_df['pred_label'] = val_sex_df['combined_cat'].apply(predict_gender)
val_sex_df.drop(columns=['text_cat', 'entities_cat', 'best_guess_cat', 'gender', 'race'], inplace=True)
val_sex_df.head()
# Out:
# <ipython-input-72-038229b2afae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_sex_df['pred_label'] = val_sex_df['combined_cat'].apply(predict_gender)
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 img                                               text  \
# 1726  img/01726.png        a real man loads the dishwasher every night
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
# 1796  img/01796.png       life hack #23 how to get stoned with no weed
# 2634  img/02634.png  and just like that... this sandwich maker doub...
# 3197  img/03197.png  i'm no bird expert but i'm guessing it's 4 fem...
#
#      gold_hate                gold_pc          gold_attack  \
# 1726   hateful                  [sex]       [dehumanizing]
# 1765   hateful            [race, sex]  [inciting_violence]
# 1796   hateful  [race, religion, sex]  [inciting_violence]
# 2634   hateful                  [sex]       [dehumanizing]
# 3197   hateful                  [sex]       [dehumanizing]
#
#            best_guess_labels  \
# 1726  خودکشی مجری رادیو مشهد
# 1765                  poster
# 1796              photograph
# 2634                   grass
# 3197                   fauna
#
#                                                entities manual_label  \
# 1726  [Health, Human sexual activity, Sleep, Reprodu...       female
# 1765  [Stock photography, , Getty Images, Image, Pho...         LGBT
# 1796  [Photograph, Hug, Photo caption, Product, Frie...         LGBT
# 2634  [Stock photography, Getty Images, , Photograph...       female
# 3197  [Pacific swallow, Birds, Barn swallow, Stock p...       female
#
#        difficulty_level                                       text_cleaned  \
# 1726                     [a, real, man, load, the, dishwasher, every, n...
# 1765     context_medium  [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796  context_difficult  [life, hack, #, 23, how, to, get, stoned, with...
# 2634                     [and, just, like, that, , this, sandwich, make...
# 3197                     [i, am, no, bird, expert, but, i, am, guessing...
#
#         best_guess_labels_cleaned  \
# 1726  [خودکشی, مجری, رادیو, مشهد]
# 1765                     [poster]
# 1796                 [photograph]
# 2634                      [grass]
# 3197                      [fauna]
#
#                                        entities_cleaned    combined_cat  \
# 1726  [health, human, sexual, activity, sleep, repro...  [male, female]
# 1765  [stock, photography, getty, image, image, phot...        [female]
# 1796  [photograph, hug, photo, caption, product, fri...              []
# 2634  [stock, photography, getty, image, photograph,...        [female]
# 3197  [pacific, swallow, bird, barn, swallow, stock,...  [female, male]
#
#         pred_label
# 1726         Mixed
# 1765        female
# 1796  Unidentified
# 2634        female
# 3197         Mixed

# %%
print(val_sex_df[val_sex_df['combined_cat'].apply(len) != 0].shape)
print(val_sex_df[val_sex_df['combined_cat'].apply(len) == 0].shape)
# Out:
# (41, 14)
# (15, 14)

# %%
print(val_sex_df[val_sex_df['pred_label'] == val_sex_df['manual_label']].shape)
print(val_sex_df[val_sex_df['pred_label'] != val_sex_df['manual_label']].shape)
# Out:
# (31, 14)
# (25, 14)

# %%
mislabel_df = val_sex_df[(val_sex_df['pred_label'] != val_sex_df['manual_label']) & (val_sex_df['pred_label'] != 'Unidentified')]
print(mislabel_df.shape)
mislabel_df
# Out:
# (10, 14)
#                  img                                               text  \
# 1726   img/01726.png        a real man loads the dishwasher every night
# 1765   img/01765.png  after a girl dies, what organ in her body stay...
# 3197   img/03197.png  i'm no bird expert but i'm guessing it's 4 fem...
# 4769   img/04769.png  if she's pouting like this and you don't immed...
# 24396  img/24396.png  so like, why are men even gay? girls have butt...
# 27498  img/27498.png  who's gonna make the sandwiches? what do we do...
# 48296  img/48296.png  when you date an asian boy and you trynna get ...
# 74906  img/74906.png             are you a boy or a girl i'm non binary
# 84510  img/84510.png  bartender: how about a nice 12 yr old? him: bo...
# 91836  img/91836.png  one of my 5 boyfriends slept with another girl...
#
#       gold_hate            gold_pc          gold_attack  \
# 1726    hateful              [sex]       [dehumanizing]
# 1765    hateful        [race, sex]  [inciting_violence]
# 3197    hateful              [sex]       [dehumanizing]
# 4769    hateful              [sex]           [contempt]
# 24396   hateful              [sex]           [contempt]
# 27498   hateful              [sex]       [dehumanizing]
# 48296   hateful        [sex, race]        [inferiority]
# 74906   hateful  [sex, disability]        [inferiority]
# 84510   hateful    [religion, sex]       [dehumanizing]
# 91836   hateful              [sex]        [inferiority]
#
#             best_guess_labels  \
# 1726   خودکشی مجری رادیو مشهد
# 1765                   poster
# 3197                    fauna
# 4769                  sitting
# 24396                  beauty
# 27498           photo caption
# 48296           photo caption
# 74906              photograph
# 84510     getty images priest
# 91836           photo caption
#
#                                                 entities manual_label  \
# 1726   [Health, Human sexual activity, Sleep, Reprodu...       female
# 1765   [Stock photography, , Getty Images, Image, Pho...         LGBT
# 3197   [Pacific swallow, Birds, Barn swallow, Stock p...       female
# 4769   [Product design, , Font, Abdomen, Photo captio...       female
# 24396  [Forehead, Face, Lips, Black hair, Photo capti...         male
# 27498                      [Bride, Photo caption, Meter]         LGBT
# 48296  [Mammal, Human behavior, Hug, Human, Happiness...       female
# 74906  [Photograph, Wheelchair, iStock, Stock photogr...         LGBT
# 84510  [Stock photography, stock.xchng, Image, , Gett...         male
# 91836  [Stock photography, Web colors, Color scheme, ...       female
#
#       difficulty_level                                       text_cleaned  \
# 1726                    [a, real, man, load, the, dishwasher, every, n...
# 1765    context_medium  [after, a, girl, dy, ,, what, organ, in, her, ...
# 3197                    [i, am, no, bird, expert, but, i, am, guessing...
# 4769                    [if, she, is, pouting, like, this, and, you, d...
# 24396                   [so, like, ,, why, are, men, even, gay, , girl...
# 27498                   [who, is, going, to, make, the, sandwich, , wh...
# 48296                   [when, you, date, an, asian, boy, and, you, tr...
# 74906                   [are, you, a, boy, or, a, girl, i, am, non, bi...
# 84510                   [bartender, , how, about, a, nice, 12, yr, old...
# 91836                   [one, of, my, 5, boyfriend, slept, with, anoth...
#
#          best_guess_labels_cleaned  \
# 1726   [خودکشی, مجری, رادیو, مشهد]
# 1765                      [poster]
# 3197                       [fauna]
# 4769                     [sitting]
# 24396                     [beauty]
# 27498             [photo, caption]
# 48296             [photo, caption]
# 74906                 [photograph]
# 84510       [getty, image, priest]
# 91836             [photo, caption]
#
#                                         entities_cleaned  \
# 1726   [health, human, sexual, activity, sleep, repro...
# 1765   [stock, photography, getty, image, image, phot...
# 3197   [pacific, swallow, bird, barn, swallow, stock,...
# 4769   [product, design, font, abdomen, photo, captio...
# 24396  [forehead, face, lip, black, hair, photo, capt...
# 27498                     [bride, photo, caption, meter]
# 48296  [mammal, human, behavior, hug, human, happines...
# 74906  [photograph, wheelchair, istock, stock, photog...
# 84510  [stock, photography, stockxchng, image, getty,...
# 91836  [stock, photography, web, color, color, scheme...
#
#                combined_cat pred_label
# 1726         [male, female]      Mixed
# 1765               [female]     female
# 3197         [female, male]      Mixed
# 4769         [female, LGBT]       LGBT
# 24396  [male, LGBT, female]       LGBT
# 27498      [female, female]     female
# 48296                [male]       male
# 74906        [male, female]      Mixed
# 84510        [male, female]      Mixed
# 91836        [female, male]      Mixed

# %%
unlabel_df = train_sex_df[(train_sex_df['pred_label'] != train_sex_df['manual_label']) & (train_sex_df['pred_label'] == 'Unidentified')]
print(unlabel_df.shape)
unlabel_df
# Out:
# (21, 19)
#                  img                                               text  \
# 10328  img/10328.png  how dikes look when they're in line paying for...
# 13620  img/13620.png  when you get shot in the groin by a rubber bul...
# 17236  img/17236.png  this just in caitlyn jenner claims bruce fondl...
# 17326  img/17326.png         what the neighbors see what my father sees
# 25847  img/25847.png  they should not be allowed to have kids you ma...
# 27489  img/27489.png  how do we destroy the patriarchy? it's simple....
# 27956  img/27956.png                   companies when pride month ends:
# 29703  img/29703.png              when each letter is a mental disorder
# 30692  img/30692.png  cameraman: i don't understan- psychic kid: tru...
# 37628  img/37628.png  when your uber driver arrives but you're proba...
# 40321  img/40321.png                  i want you to stop being a faggot
# 41589  img/41589.png                                 bruce jenner's cat
# 43180  img/43180.png             beating things to make them work again
# 51694  img/51694.png  how do we destroy the patriarchy? it's simple....
# 54389  img/54389.png        be sure to spay or neuter your spouse today
# 61730  img/61730.png                        oh look my new wife arrived
# 65201  img/65201.png             well split my dick and call me caitlyn
# 79124  img/79124.png       luigi got big tiddies i don't support faggot
# 86071  img/86071.png  when the deaf kids are roasting you in sign la...
# 96405  img/96405.png  execute a plan to accept your actual born sex....
# 98756  img/98756.png  this dude wants to use the same restroom as yo...
#
#       gold_hate gold_pc            gold_attack  \
# 10328   hateful   [sex]                [slurs]
# 13620   hateful   [sex]    [inciting_violence]
# 17236   hateful   [sex]          [inferiority]
# 17326   hateful   [sex]    [inciting_violence]
# 25847   hateful   [sex]  [contempt, exclusion]
# 27489   hateful   [sex]          [inferiority]
# 27956   hateful   [sex]         [dehumanizing]
# 29703   hateful   [sex]          [inferiority]
# 30692   hateful   [sex]         [attack_empty]
# 37628   hateful   [sex]          [inferiority]
# 40321   hateful   [sex]                [slurs]
# 41589   hateful   [sex]          [inferiority]
# 43180   hateful   [sex]    [inciting_violence]
# 51694   hateful   [sex]          [inferiority]
# 54389   hateful   [sex]         [dehumanizing]
# 61730   hateful   [sex]         [dehumanizing]
# 65201   hateful   [sex]          [inferiority]
# 79124   hateful   [sex]      [contempt, slurs]
# 86071   hateful   [sex]          [inferiority]
# 96405   hateful   [sex]          [inferiority]
# 98756   hateful   [sex]             [contempt]
#
#                        best_guess_labels  \
# 10328                      photo caption
# 13620                      photo caption
# 17236                             poster
# 17326                         photograph
# 25847  mi sono innamorata di una ragazza
# 27489                              smile
# 27956                           shoulder
# 29703                            eyewear
# 30692                      9/11 memorial
# 37628                            driving
# 40321                          imprentas
# 41589                    al baghdadi dog
# 43180                 پنل تلویزیون کنترل
# 51694                      photo caption
# 54389                      trailer trash
# 61730                        Photography
# 65201                                lip
# 79124                           wrestler
# 86071                         niño sordo
# 96405                      photo caption
# 98756                      photo caption
#
#                                                 entities  \
# 10328  [Image, Stock photography, Photograph, Getty I...
# 13620                        [Photo caption, Font, Dude]
# 17236                            [Poster, Photo caption]
# 17326  [Stock photography, , Image, , Getty Images, P...
# 25847  [Friendship, Lesbiaeth, Kiss, Multiracial peop...
# 27489  [Stock photography, , Getty Images, Photo capt...
# 27956  [Stock photography, Anytime Plumbing & Solutio...
# 29703  [Product design, Brand, Product, Smiley, Line,...
# 30692  [World Trade Center, 9/11 Memorial & Museum, ,...
# 37628  [Car, Driving, , Getty Images, Image, Stock ph...
# 40321  [Human behavior, Photo caption, Font, Behavior...
# 41589  [Death of Abu Bakr al-Baghdadi, Conan, Belgian...
# 43180  [Television, Over-the-top media service, , , S...
# 51694  [Stock photography, , Getty Images, Photo capt...
# 54389  [White trash, Hillbilly, Redneck, Stock photog...
# 61730  [Stock photography, , Image, Photography, Gett...
# 65201  [Caitlyn Jenner, , , Celebrity, Television, , ...
# 79124  [Professional wrestling, Wrestling, Pradal ser...
# 86071  [Hearing loss, Sign language, Deafness, Infant...
# 96405  [Infant, Human behavior, Snout, Laughter, Todd...
# 98756  [Bangs, Forehead, Hair coloring, Layered hair,...
#
#                                          gender  \
# 10328  [Female, Female, Female, Female, Female]
# 13620                              [Male, Male]
# 17236                      [Female, Male, Male]
# 17326          [Female, Female, Female, Female]
# 25847                  [Female, Female, Female]
# 27489                                  [Female]
# 27956                        [Male, Male, Male]
# 29703                                        []
# 30692                                        []
# 37628                  [Female, Female, Female]
# 40321                              [Male, Male]
# 41589                                        []
# 43180                          [Female, Female]
# 51694                                  [Female]
# 54389                                  [Female]
# 61730                          [Female, Female]
# 65201                                  [Female]
# 79124                  [Male, Male, Male, Male]
# 86071    [Male, Female, Female, Female, Female]
# 96405                                  [Female]
# 98756                                  [Female]
#
#                                                     race manual_label  \
# 10328  [Latino_Hispanic, White, White, Latino_Hispani...         LGBT
# 13620                                     [Black, Black]         LGBT
# 17236                              [White, White, White]         LGBT
# 17326                       [White, White, White, White]       female
# 25847                              [White, White, White]         LGBT
# 27489                                            [White]       female
# 27956                              [White, White, White]         LGBT
# 29703                                                 []         LGBT
# 30692                                                 []   Mislabeled
# 37628  [Southeast Asian, Southeast Asian, Southeast A...       female
# 40321                   [Middle Eastern, Middle Eastern]         LGBT
# 41589                                                 []         LGBT
# 43180                                     [White, White]       female
# 51694                                            [White]       female
# 54389                                            [White]         LGBT
# 61730                                     [White, White]       female
# 65201                                            [White]         LGBT
# 79124                     [Indian, White, Indian, White]         LGBT
# 86071                [White, White, White, White, White]   Mislabeled
# 96405                                            [White]         LGBT
# 98756                                            [White]         LGBT
#
#                     difficulty_level  \
# 10328                      text_easy
# 13620                      text_easy
# 17236                      text_easy
# 17326                 context_medium
# 25847                 context_medium
# 27489                 context_medium
# 27956                 context_medium
# 29703                 context_medium
# 30692
# 37628  context_medium&knowledge_hard
# 40321                      text_easy
# 41589                 knowledge_hard
# 43180                 context_medium
# 51694                 context_medium
# 54389                      text_easy
# 61730                 context_medium
# 65201                      text_easy
# 79124                 context_medium
# 86071
# 96405                      text_easy
# 98756                      text_easy
#
#                                             text_cleaned  \
# 10328  [how, dike, look, when, they, are, in, line, p...
# 13620  [when, you, get, shot, in, the, groin, by, a, ...
# 17236  [this, just, in, caitlyn, jenner, claim, bruce...
# 17326  [what, the, neighbor, see, what, my, father, see]
# 25847  [they, should, not, be, allowed, to, have, kid...
# 27489  [how, do, we, destroy, the, patriarchy, , it, ...
# 27956               [company, when, pride, month, end, ]
# 29703      [when, each, letter, is, a, mental, disorder]
# 30692  [cameraman, , i, do, not, understan-, psychic,...
# 37628  [when, your, uber, driver, arrives, but, you, ...
# 40321         [i, want, you, to, stop, being, a, faggot]
# 41589                           [bruce, jenner, 's, cat]
# 43180      [beating, thing, to, make, them, work, again]
# 51694  [how, do, we, destroy, the, patriarchy, , it, ...
# 54389  [be, sure, to, spay, or, neuter, your, spouse,...
# 61730                 [oh, look, my, new, wife, arrived]
# 65201    [well, split, my, dick, and, call, me, caitlyn]
# 79124  [luigi, got, big, tiddies, i, do, not, support...
# 86071  [when, the, deaf, kid, are, roasting, you, in,...
# 96405  [execute, a, plan, to, accept, your, actual, b...
# 98756  [this, dude, want, to, use, the, same, restroo...
#
#                       best_guess_labels_cleaned  \
# 10328                          [photo, caption]
# 13620                          [photo, caption]
# 17236                                  [poster]
# 17326                              [photograph]
# 25847  [mi, sono, innamorata, di, una, ragazza]
# 27489                                   [smile]
# 27956                                [shoulder]
# 29703                                 [eyewear]
# 30692                          [9/11, memorial]
# 37628                                 [driving]
# 40321                               [imprentas]
# 41589                       [al, baghdadi, dog]
# 43180                    [پنل, تلویزیون, کنترل]
# 51694                          [photo, caption]
# 54389                          [trailer, trash]
# 61730                             [photography]
# 65201                                     [lip]
# 79124                                [wrestler]
# 86071                             [niño, sordo]
# 96405                          [photo, caption]
# 98756                          [photo, caption]
#
#                                         entities_cleaned text_cat  \
# 10328  [image, stock, photography, photograph, getty,...       []
# 13620                       [photo, caption, font, dude]       []
# 17236                           [poster, photo, caption]       []
# 17326  [stock, photography, image, getty, image, phot...       []
# 25847  [friendship, lesbiaeth, kiss, multiracial, peo...       []
# 27489  [stock, photography, getty, image, photo, capt...       []
# 27956  [stock, photography, anytime, plumbing, &, sol...       []
# 29703  [product, design, brand, product, smiley, line...       []
# 30692  [world, trade, center, 9/11, memorial, &, muse...       []
# 37628  [car, driving, getty, image, image, stock, pho...       []
# 40321  [human, behavior, photo, caption, font, behavi...       []
# 41589  [death, of, abu, bakr, al-baghdadi, conan, bel...       []
# 43180  [television, over-the-top, medium, service, st...       []
# 51694  [stock, photography, getty, image, photo, capt...       []
# 54389  [white, trash, hillbilly, redneck, stock, phot...       []
# 61730  [stock, photography, image, photography, getty...       []
# 65201  [caitlyn, jenner, celebrity, television, image...       []
# 79124  [professional, wrestling, wrestling, pradal, s...       []
# 86071  [hearing, loss, sign, language, deafness, infa...       []
# 96405  [infant, human, behavior, snout, laughter, tod...       []
# 98756  [bang, forehead, hair, coloring, layered, hair...       []
#
#       entities_cat best_guess_cat combined_cat    pred_label
# 10328           []             []           []  Unidentified
# 13620           []             []           []  Unidentified
# 17236           []             []           []  Unidentified
# 17326           []             []           []  Unidentified
# 25847           []             []           []  Unidentified
# 27489           []             []           []  Unidentified
# 27956           []             []           []  Unidentified
# 29703           []             []           []  Unidentified
# 30692           []             []           []  Unidentified
# 37628           []             []           []  Unidentified
# 40321           []             []           []  Unidentified
# 41589           []             []           []  Unidentified
# 43180           []             []           []  Unidentified
# 51694           []             []           []  Unidentified
# 54389           []             []           []  Unidentified
# 61730           []             []           []  Unidentified
# 65201           []             []           []  Unidentified
# 79124           []             []           []  Unidentified
# 86071           []             []           []  Unidentified
# 96405           []             []           []  Unidentified
# 98756           []             []           []  Unidentified

# %% [markdown]
# # 4. Race Analysis

# %%
categories = (
    ("white", ("cracker", )),
    ("black", ("black", "obama", "barack", "gorilla", "mississippi", "nigger", "ape")),
    ("east asia", ("brown", "chinese", "asian")),
    ("middle east", ("israel", "arab", "africa"))
)

special_kws = [
    ("white", "white"),
    ("black", "dark"),
    ("american indian", "red indian"),
    ("american indian", "native american")
]

def assign_race(tokens):
    keywords, labels  = [], []
    for t in tokens:
        for cat, kws in categories:
            if t in kws:
                keywords.append((t, kws))
                labels.append(cat)
    
    sent = " ".join(tokens)
    for cat, special_kw in special_kws:
        if special_kw in sent:
            keywords.append(t)
            labels.append(cat)
    
    return labels

def predict_race(combined_cat):
    from collections import Counter
    
    if len(combined_cat) == 0:
        return "Unidentified"
    
    counter = Counter(combined_cat)
    elements = counter.most_common(2)
    
    if len(elements) == 1 or elements[0][1] > elements[1][1]:
        return elements[0][0]
    
    return "Mixed"

# %% [markdown]
# ## 4.1 Race Analysis - Train

# %%
train_race_df = train_combined_df[train_combined_df['gold_pc'].apply(lambda x: 'race' in x)]
train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0])
train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
train_race_df.head()
# Out:
# <ipython-input-78-3830e475ff93>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0])
# <ipython-input-78-3830e475ff93>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['manual_label'] = train_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
#                 img                                               text  \
# 2457  img/02457.png  i hate when i see a black out in my neighborho...
# 2719  img/02719.png      your black neighbor after you called the cops
# 3128  img/03128.png                          lazy day nothing to steal
# 3591  img/03591.png  joins the democrat party to indulge in deep se...
# 4859  img/04859.png                arnold schwarzenigger i'll be black
#
#      gold_hate gold_pc     gold_attack best_guess_labels  \
# 2457   hateful  [race]      [contempt]          kkk cool
# 2719   hateful  [race]  [dehumanizing]       bonobo male
# 3128   hateful  [race]  [dehumanizing]             tribe
# 3591   hateful  [race]  [attack_empty]        nerd girls
# 4859   hateful  [race]         [slurs]             beard
#
#                                                entities  \
# 2457  [Ku Klux Klan, Stone Mountain, Loyal White Kni...
# 2719  [Bonobo, Primate, Human, New World monkeys, Te...
# 3128  [Omo River, Hamar people, Tribe, , Arbore peop...
# 3591  [Stock photography, Photograph, Getty Images, ...
# 4859  [T-Shirt, Beard, Product, Brand, Photo caption...
#
#                         gender                   race manual_label  \
# 2457                        []                     []        black
# 2719                        []                     []        black
# 3128        [Male, Male, Male]  [Black, Black, Black]        black
# 3591  [Female, Female, Female]  [White, White, White]        black
# 4859                    [Male]                [Black]        black
#
#                     difficulty_level  \
# 2457                  context_medium
# 2719                  context_medium
# 3128  context_medium& knowledge_hard
# 3591        text_easy&context_medium
# 4859        easy_text&knowledge_hard
#
#                                            text_cleaned  \
# 2457  [i, hate, when, i, see, a, black, out, in, my,...
# 2719  [your, black, neighbor, after, you, called, th...
# 3128                    [lazy, day, nothing, to, steal]
# 3591  [join, the, democrat, party, to, indulge, in, ...
# 4859       [arnold, schwarzenigger, i, will, be, black]
#
#      best_guess_labels_cleaned  \
# 2457               [kkk, cool]
# 2719            [bonobo, male]
# 3128                   [tribe]
# 3591              [nerd, girl]
# 4859                   [beard]
#
#                                        entities_cleaned
# 2457  [ku, klux, klan, stone, mountain, loyal, white...
# 2719  [bonobo, primate, human, new, world, monkey, t...
# 3128  [omo, river, hamar, people, tribe, arbore, peo...
# 3591  [stock, photography, photograph, getty, image,...
# 4859  [t-shirt, beard, product, brand, photo, captio...

# %%
train_race_df['manual_label'].value_counts()
# Out:
# black              62
# ???                16
# white               9
# middle east         5
# east asia           4
# american indian     3
# asian               1
# Name: manual_label, dtype: int64

# %%
train_race_df['text_cat'] = train_race_df['text_cleaned'].apply(assign_race)
train_race_df['entities_cat'] = train_race_df['entities_cleaned'].apply(assign_race)
train_race_df['best_guess_cat'] = train_race_df['best_guess_labels_cleaned'].apply(assign_race)

train_race_df['combined_cat'] = train_race_df['text_cat'] + train_race_df['entities_cat'] + train_race_df['best_guess_cat']
# Out:
# <ipython-input-80-a81516721b80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['text_cat'] = train_race_df['text_cleaned'].apply(assign_race)
# <ipython-input-80-a81516721b80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['entities_cat'] = train_race_df['entities_cleaned'].apply(assign_race)
# <ipython-input-80-a81516721b80>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['best_guess_cat'] = train_race_df['best_guess_labels_cleaned'].apply(assign_race)
# <ipython-input-80-a81516721b80>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['combined_cat'] = train_race_df['text_cat'] + train_race_df['entities_cat'] + train_race_df['best_guess_cat']

# %%
train_race_df.head()
# Out:
#                 img                                               text  \
# 2457  img/02457.png  i hate when i see a black out in my neighborho...
# 2719  img/02719.png      your black neighbor after you called the cops
# 3128  img/03128.png                          lazy day nothing to steal
# 3591  img/03591.png  joins the democrat party to indulge in deep se...
# 4859  img/04859.png                arnold schwarzenigger i'll be black
#
#      gold_hate gold_pc     gold_attack best_guess_labels  \
# 2457   hateful  [race]      [contempt]          kkk cool
# 2719   hateful  [race]  [dehumanizing]       bonobo male
# 3128   hateful  [race]  [dehumanizing]             tribe
# 3591   hateful  [race]  [attack_empty]        nerd girls
# 4859   hateful  [race]         [slurs]             beard
#
#                                                entities  \
# 2457  [Ku Klux Klan, Stone Mountain, Loyal White Kni...
# 2719  [Bonobo, Primate, Human, New World monkeys, Te...
# 3128  [Omo River, Hamar people, Tribe, , Arbore peop...
# 3591  [Stock photography, Photograph, Getty Images, ...
# 4859  [T-Shirt, Beard, Product, Brand, Photo caption...
#
#                         gender                   race manual_label  \
# 2457                        []                     []        black
# 2719                        []                     []        black
# 3128        [Male, Male, Male]  [Black, Black, Black]        black
# 3591  [Female, Female, Female]  [White, White, White]        black
# 4859                    [Male]                [Black]        black
#
#                     difficulty_level  \
# 2457                  context_medium
# 2719                  context_medium
# 3128  context_medium& knowledge_hard
# 3591        text_easy&context_medium
# 4859        easy_text&knowledge_hard
#
#                                            text_cleaned  \
# 2457  [i, hate, when, i, see, a, black, out, in, my,...
# 2719  [your, black, neighbor, after, you, called, th...
# 3128                    [lazy, day, nothing, to, steal]
# 3591  [join, the, democrat, party, to, indulge, in, ...
# 4859       [arnold, schwarzenigger, i, will, be, black]
#
#      best_guess_labels_cleaned  \
# 2457               [kkk, cool]
# 2719            [bonobo, male]
# 3128                   [tribe]
# 3591              [nerd, girl]
# 4859                   [beard]
#
#                                        entities_cleaned text_cat entities_cat  \
# 2457  [ku, klux, klan, stone, mountain, loyal, white...  [black]      [white]
# 2719  [bonobo, primate, human, new, world, monkey, t...  [black]           []
# 3128  [omo, river, hamar, people, tribe, arbore, peo...       []           []
# 3591  [stock, photography, photograph, getty, image,...  [black]           []
# 4859  [t-shirt, beard, product, brand, photo, captio...  [black]           []
#
#      best_guess_cat    combined_cat
# 2457             []  [black, white]
# 2719             []         [black]
# 3128             []              []
# 3591             []         [black]
# 4859             []         [black]

# %%
train_race_df['pred_label'] = train_race_df['combined_cat'].apply(predict_gender)
train_race_df.drop(columns=['text_cat', 'entities_cat', 'best_guess_cat'], inplace=True)
train_race_df.head()
# Out:
# <ipython-input-82-ef8034dc1b63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_race_df['pred_label'] = train_race_df['combined_cat'].apply(predict_gender)
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 img                                               text  \
# 2457  img/02457.png  i hate when i see a black out in my neighborho...
# 2719  img/02719.png      your black neighbor after you called the cops
# 3128  img/03128.png                          lazy day nothing to steal
# 3591  img/03591.png  joins the democrat party to indulge in deep se...
# 4859  img/04859.png                arnold schwarzenigger i'll be black
#
#      gold_hate gold_pc     gold_attack best_guess_labels  \
# 2457   hateful  [race]      [contempt]          kkk cool
# 2719   hateful  [race]  [dehumanizing]       bonobo male
# 3128   hateful  [race]  [dehumanizing]             tribe
# 3591   hateful  [race]  [attack_empty]        nerd girls
# 4859   hateful  [race]         [slurs]             beard
#
#                                                entities  \
# 2457  [Ku Klux Klan, Stone Mountain, Loyal White Kni...
# 2719  [Bonobo, Primate, Human, New World monkeys, Te...
# 3128  [Omo River, Hamar people, Tribe, , Arbore peop...
# 3591  [Stock photography, Photograph, Getty Images, ...
# 4859  [T-Shirt, Beard, Product, Brand, Photo caption...
#
#                         gender                   race manual_label  \
# 2457                        []                     []        black
# 2719                        []                     []        black
# 3128        [Male, Male, Male]  [Black, Black, Black]        black
# 3591  [Female, Female, Female]  [White, White, White]        black
# 4859                    [Male]                [Black]        black
#
#                     difficulty_level  \
# 2457                  context_medium
# 2719                  context_medium
# 3128  context_medium& knowledge_hard
# 3591        text_easy&context_medium
# 4859        easy_text&knowledge_hard
#
#                                            text_cleaned  \
# 2457  [i, hate, when, i, see, a, black, out, in, my,...
# 2719  [your, black, neighbor, after, you, called, th...
# 3128                    [lazy, day, nothing, to, steal]
# 3591  [join, the, democrat, party, to, indulge, in, ...
# 4859       [arnold, schwarzenigger, i, will, be, black]
#
#      best_guess_labels_cleaned  \
# 2457               [kkk, cool]
# 2719            [bonobo, male]
# 3128                   [tribe]
# 3591              [nerd, girl]
# 4859                   [beard]
#
#                                        entities_cleaned    combined_cat  \
# 2457  [ku, klux, klan, stone, mountain, loyal, white...  [black, white]
# 2719  [bonobo, primate, human, new, world, monkey, t...         [black]
# 3128  [omo, river, hamar, people, tribe, arbore, peo...              []
# 3591  [stock, photography, photograph, getty, image,...         [black]
# 4859  [t-shirt, beard, product, brand, photo, captio...         [black]
#
#         pred_label
# 2457         Mixed
# 2719         black
# 3128  Unidentified
# 3591         black
# 4859         black

# %%
print(train_race_df[(train_race_df['combined_cat'].apply(len) != 0) & (train_race_df['manual_label'] != '???')].shape)
print(train_race_df[(train_race_df['combined_cat'].apply(len) == 0) & (train_race_df['manual_label'] != '???')].shape)
# Out:
# (63, 16)
# (21, 16)

# %%
print(train_race_df[(train_race_df['pred_label'] == train_race_df['manual_label']) & (train_race_df['manual_label'] != '???')].shape)
print(train_race_df[(train_race_df['pred_label'] != train_race_df['manual_label']) & (train_race_df['manual_label'] != '???')].shape)
# Out:
# (52, 16)
# (32, 16)

# %%
mislabel_df = train_race_df[(train_race_df['pred_label'] != train_race_df['manual_label']) & (train_race_df['pred_label'] != 'Unidentified') & (train_race_df['manual_label'] != '???')]

print(mislabel_df.shape)
mislabel_df
# Out:
# (11, 16)
#                  img                                               text  \
# 2457   img/02457.png  i hate when i see a black out in my neighborho...
# 26735  img/26735.png  you pick cotton to get to it because it's whit...
# 57631  img/57631.png   adding coolant when the farm equipment overheats
# 59410  img/59410.png  stop racism black children and white children ...
# 60173  img/60173.png  white people dont shoot eachother in the stree...
# 60985  img/60985.png  when you got an itch on your back that you can...
# 62931  img/62931.png  i'm sure people who lived in the bible where w...
# 81245  img/81245.png  when you are hanging out with your black frien...
# 82163  img/82163.png                             please make them white
# 96354  img/96354.png  why do asians have eyes like this? isn't it ha...
# 97013  img/97013.png    why is cocaine white? because it actually works
#
#       gold_hate gold_pc              gold_attack  best_guess_labels  \
# 2457    hateful  [race]               [contempt]           kkk cool
# 26735   hateful  [race]                [mocking]      photo caption
# 57631   hateful  [race]  [dehumanizing, mocking]              human
# 59410   hateful  [race]           [dehumanizing]     bambino 1 anno
# 60173   hateful  [race]           [dehumanizing]             School
# 60985   hateful  [race]                [mocking]       willie lynch
# 62931   hateful  [race]           [dehumanizing]           standing
# 81245   hateful  [race]                  [slurs]  1980's dark alley
# 82163   hateful  [race]           [attack_empty]                fur
# 96354   hateful  [race]            [inferiority]        dogecoin up
# 97013   hateful  [race]            [inferiority]  stock photography
#
#                                                 entities  \
# 2457   [Ku Klux Klan, Stone Mountain, Loyal White Kni...
# 26735  [Rat, Photo caption, Whiskers, Organism, Meter...
# 57631  [Human, Africa, Human head, Human body, , stoc...
# 59410  [Infant, , Horoscope, Baby Food, Family, Week,...
# 60173  [Graduation ceremony, Madeira High School, Sch...
# 60985  [The Black Man's Lament; Or, how to Make Sugar...
# 62931  [Online quiz, T-Shirt, Human behavior, Centrov...
# 81245  [1990s, 1980s, Stock photography, Photograph, ...
# 82163              [Erotica, Literature, Blond, , Fur'M]
# 96354  [Dogecoin, Cryptocurrency, Bitcoin, Shiba Inu ...
# 97013  [Black and white, Stock photography, Photograp...
#
#                                                   gender  \
# 2457                                                  []
# 26735                                                 []
# 57631                                       [Male, Male]
# 59410                                           [Female]
# 60173                 [Female, Male, Female, Male, Male]
# 60985                                 [Male, Male, Male]
# 62931                                       [Male, Male]
# 81245                                             [Male]
# 82163  [Female, Female, Female, Female, Female, Femal...
# 96354                                                 []
# 97013                                                 []
#
#                                                     race manual_label  \
# 2457                                                  []        black
# 26735                                                 []        black
# 57631                                     [Black, Black]        black
# 59410                                            [White]        black
# 60173  [Latino_Hispanic, Black, White, East Asian, Ea...        black
# 60985            [White, Middle Eastern, Middle Eastern]        black
# 62931                                     [Black, Black]        black
# 81245                                            [White]        white
# 82163  [White, White, White, White, White, White, White]        black
# 96354                                                 []        asian
# 97013                                                 []        black
#
#       difficulty_level                                       text_cleaned  \
# 2457    context_medium  [i, hate, when, i, see, a, black, out, in, my,...
# 26735        text_easy  [you, pick, cotton, to, get, to, it, because, ...
# 57631   knowledge_hard  [adding, coolant, when, the, farm, equipment, ...
# 59410   context_medium  [stop, racism, black, child, and, white, child...
# 60173        text_easy  [white, people, do, not, shoot, eachother, in,...
# 60985   context_medium  [when, you, got, an, itch, on, your, back, tha...
# 62931        text_easy  [i, am, sure, people, who, lived, in, the, bib...
# 81245        text_easy  [when, you, are, hanging, out, with, your, bla...
# 82163        text_easy                        [please, make, them, white]
# 96354   context_medium  [why, do, asian, have, eye, like, this, , is, ...
# 97013   knowledge_hard  [why, is, cocaine, white, , because, it, actua...
#
#       best_guess_labels_cleaned  \
# 2457                [kkk, cool]
# 26735          [photo, caption]
# 57631                   [human]
# 59410        [bambino, 1, anno]
# 60173                  [school]
# 60985           [willie, lynch]
# 62931                [standing]
# 81245   [1980, 's, dark, alley]
# 82163                     [fur]
# 96354            [dogecoin, up]
# 97013      [stock, photography]
#
#                                         entities_cleaned  \
# 2457   [ku, klux, klan, stone, mountain, loyal, white...
# 26735  [rat, photo, caption, whisker, organism, meter...
# 57631  [human, africa, human, head, human, body, stoc...
# 59410  [infant, horoscope, baby, food, family, week, ...
# 60173  [graduation, ceremony, madeira, high, school, ...
# 60985  [the, black, man, 's, lament, , or, ,, how, to...
# 62931  [online, quiz, t-shirt, human, behavior, centr...
# 81245  [1990s, 1980s, stock, photography, photograph,...
# 82163              [erotica, literature, blond, fur, 'm]
# 96354  [dogecoin, cryptocurrency, bitcoin, shiba, inu...
# 97013  [black, and, white, stock, photography, photog...
#
#                        combined_cat   pred_label
# 2457                 [black, white]        Mixed
# 26735                [black, white]        Mixed
# 57631                 [middle east]  middle east
# 59410                [black, white]        Mixed
# 60173                [black, white]        Mixed
# 60985                [white, black]        Mixed
# 62931                [black, white]        Mixed
# 81245         [black, white, black]        black
# 82163                       [white]        white
# 96354                   [east asia]    east asia
# 97013  [white, black, black, white]        Mixed

# %%
unlabel_df = train_race_df[(train_race_df['pred_label'] != train_race_df['manual_label']) & (train_race_df['pred_label'] == 'Unidentified') & (train_race_df['manual_label'] != '???')]

print(unlabel_df.shape)
unlabel_df
# Out:
# (21, 16)
#                  img                                               text  \
# 3128   img/03128.png                          lazy day nothing to steal
# 7236   img/07236.png  when you realize that "ginger" is just the n-w...
# 13875  img/13875.png                 i see a cat let's get it for lunch
# 20738  img/20738.png  if being racist means i don't want my country ...
# 21674  img/21674.png  hey bro i'm not racist bro but ever noticed po...
# 23910  img/23910.png        baby look like he pay his own child support
# 24783  img/24783.png  when you go out to fight for independence but ...
# 25984  img/25984.png                  whipepo reading the comments like
# 28735  img/28735.png               morgan freeman morgan not-so-freeman
# 34872  img/34872.png  i bet god is one of us because he didn't even ...
# 37180  img/37180.png  look dad im doing it you did it tyrone! you st...
# 45207  img/45207.png        a new target for entry level police academy
# 47385  img/47385.png       yall got any more a them cracka ass crackas?
# 57302  img/57302.png  because they love you they want this not they ...
# 61780  img/61780.png  you may be a racist if.. your response to a qu...
# 67092  img/67092.png  when your teacher and classmates make fun of y...
# 69125  img/69125.png                 police academy graduation ceremony
# 69804  img/69804.png                              thats a little savage
# 84910  img/84910.png      take that monkey shit off! you embarassin' us
# 89621  img/89621.png  if she wears this out in public she is on sect...
# 97058  img/97058.png  doctor: take this medicine after food african ...
#
#       gold_hate gold_pc                  gold_attack   best_guess_labels  \
# 3128    hateful  [race]               [dehumanizing]               tribe
# 7236    hateful  [race]                      [slurs]  femme jeune rousse
# 13875   hateful  [race]                [inferiority]            official
# 20738   hateful  [race]                   [contempt]             firearm
# 21674   hateful  [race]  [dehumanizing, inferiority]            cool dog
# 23910   hateful  [race]                [inferiority]                head
# 24783   hateful  [race]                    [mocking]              battle
# 25984   hateful  [race]               [dehumanizing]             macaque
# 28735   hateful  [race]                    [mocking]             Slavery
# 34872   hateful  [race]                [inferiority]       photo caption
# 37180   hateful  [race]               [dehumanizing]                male
# 45207   hateful  [race]          [inciting_violence]                 lip
# 47385   hateful  [race]                      [slurs]          Restaurant
# 57302   hateful  [race]               [dehumanizing]              Parent
# 61780   hateful  [race]                   [contempt]       photo caption
# 67092   hateful  [race]          [inciting_violence]       liberia ak 47
# 69125   hateful  [race]               [dehumanizing]                 car
# 69804   hateful  [race]               [dehumanizing]             cartoon
# 84910   hateful  [race]               [dehumanizing]                 fun
# 89621   hateful  [race]               [dehumanizing]       photo caption
# 97058   hateful  [race]                [inferiority]       photo caption
#
#                                                 entities  \
# 3128   [Omo River, Hamar people, Tribe, , Arbore peop...
# 7236   [Stock photography, Portrait, Image, Illustrat...
# 13875  [Kim Jong-il, North Korea, Supreme Leader of N...
# 20738  [Keanu Reeves, Gun, , , John Wick: Chapter 2, ...
# 21674  [Siberian Husky, Puppy, Husky, Sled dog, iStoc...
# 23910  [Name, Infant, Youth, , Middle name, Nickname,...
# 24783  [Infantry, Battle, Military organization, Troo...
# 25984  [Macaques, Organism, Fauna, Photo caption, Snout]
# 28735  [Slavery, Abolitionism, History of slavery, Hi...
# 34872  [Facial hair, Photo caption, Gentleman, Dude, ...
# 37180  [DHI Doug Handlin Insurance, Image, Stock phot...
# 45207  [iStock, Stock photography, Image, Portrait, P...
# 47385  [Empress Restaurant, Restaurant, Drinking, Bre...
# 57302  [Parent, Only child, Parenting, , Family, Infa...
# 61780  [Public Relations, Photo caption, Conversation...
# 67092  [Liberia, Kalashnikov rifle, Children in the m...
# 69125  [Car, The Law Office of Erica Rodriguez, , Law...
# 69804  [Cartoon, Illustration, Getty Images, , Image,...
# 84910  [Photography, Portrait, Photographer, Image, V...
# 89621  [Stock photography, Photo caption, Photograph,...
# 97058  [Stock photography, Photograph, , Getty Images...
#
#                                                   gender  \
# 3128                                  [Male, Male, Male]
# 7236                                            [Female]
# 13875         [Male, Male, Male, Male, Male, Male, Male]
# 20738                                       [Male, Male]
# 21674                                                 []
# 23910                                       [Male, Male]
# 24783                                                 []
# 25984                                                 []
# 28735                                             [Male]
# 34872                                             [Male]
# 37180                                           [Female]
# 45207                                                 []
# 47385                     [Male, Female, Female, Female]
# 57302                       [Male, Female, Female, Male]
# 61780                       [Male, Female, Female, Male]
# 67092                                   [Female, Female]
# 69125                                           [Female]
# 69804                                           [Female]
# 84910  [Male, Male, Female, Male, Male, Male, Male, F...
# 89621                                   [Female, Female]
# 97058                           [Male, Male, Male, Male]
#
#                                                     race manual_label  \
# 3128                               [Black, Black, Black]        black
# 7236                                             [White]        black
# 13875  [Southeast Asian, Southeast Asian, Southeast A...    east asia
# 20738                                     [White, White]  middle east
# 21674                                                 []        black
# 23910                                     [Black, Black]        black
# 24783                                                 []        black
# 25984                                                 []        white
# 28735                                            [Black]        black
# 34872                                            [Black]        black
# 37180                                  [Latino_Hispanic]        black
# 45207                                                 []        black
# 47385                       [White, White, White, White]        white
# 57302                       [Black, White, White, Black]        black
# 61780                       [White, White, White, White]        black
# 67092                                     [Black, Black]        black
# 69125                                  [Southeast Asian]        black
# 69804                                            [White]        black
# 84910  [Black, Black, White, White, Black, White, Bla...        black
# 89621                 [Southeast Asian, Southeast Asian]        black
# 97058                       [Black, Black, Black, Black]  middle east
#
#                      difficulty_level  \
# 3128   context_medium& knowledge_hard
# 7236                   knowledge_hard
# 13875                  knowledge_hard
# 20738
# 21674                      text_image
# 23910   context_medium&knowledge_hard
# 24783  context_medium& knowledge_hard
# 25984                       text_easy
# 28735                  knowledge_hard
# 34872                  context_medium
# 37180                  context_medium
# 45207                  context_medium
# 47385                       text_easy
# 57302                  context_medium
# 61780                       text_easy
# 67092                  context_medium
# 69125                  context_medium
# 69804                  context_medium
# 84910                  context_medium
# 89621                  context_medium
# 97058  context_medium& knowledge_hard
#
#                                             text_cleaned  \
# 3128                     [lazy, day, nothing, to, steal]
# 7236   [when, you, realize, that, ginger, is, just, t...
# 13875      [i, see, a, cat, let, u, get, it, for, lunch]
# 20738  [if, being, racist, mean, i, do, not, want, my...
# 21674  [hey, bro, i, am, not, racist, bro, but, ever,...
# 23910  [baby, look, like, he, pay, his, own, child, s...
# 24783  [when, you, go, out, to, fight, for, independe...
# 25984             [whipepo, reading, the, comment, like]
# 28735          [morgan, freeman, morgan, not-so-freeman]
# 34872  [i, bet, god, is, one, of, u, because, he, did...
# 37180  [look, dad, i, am, doing, it, you, did, it, ty...
# 45207  [a, new, target, for, entry, level, police, ac...
# 47385  [you, all, got, any, more, a, them, cracka, as...
# 57302  [because, they, love, you, they, want, this, n...
# 61780  [you, may, be, a, racist, if, your, response, ...
# 67092  [when, your, teacher, and, classmate, make, fu...
# 69125            [police, academy, graduation, ceremony]
# 69804                      [that, is, a, little, savage]
# 84910  [take, that, monkey, shit, off, , you, embaras...
# 89621  [if, she, wear, this, out, in, public, she, is...
# 97058  [doctor, , take, this, medicine, after, food, ...
#
#       best_guess_labels_cleaned  \
# 3128                    [tribe]
# 7236     [femme, jeune, rousse]
# 13875                [official]
# 20738                 [firearm]
# 21674               [cool, dog]
# 23910                    [head]
# 24783                  [battle]
# 25984                 [macaque]
# 28735                 [slavery]
# 34872          [photo, caption]
# 37180                    [male]
# 45207                     [lip]
# 47385              [restaurant]
# 57302                  [parent]
# 61780          [photo, caption]
# 67092         [liberia, ak, 47]
# 69125                     [car]
# 69804                 [cartoon]
# 84910                     [fun]
# 89621          [photo, caption]
# 97058          [photo, caption]
#
#                                         entities_cleaned combined_cat  \
# 3128   [omo, river, hamar, people, tribe, arbore, peo...           []
# 7236   [stock, photography, portrait, image, illustra...           []
# 13875  [kim, jong-il, north, korea, supreme, leader, ...           []
# 20738  [keanu, reef, gun, john, wick, , chapter, 2, m...           []
# 21674  [siberian, husky, puppy, husky, sled, dog, ist...           []
# 23910  [name, infant, youth, middle, name, nickname, ...           []
# 24783  [infantry, battle, military, organization, tro...           []
# 25984  [macaque, organism, fauna, photo, caption, snout]           []
# 28735  [slavery, abolitionism, history, of, slavery, ...           []
# 34872  [facial, hair, photo, caption, gentleman, dude...           []
# 37180  [dhi, doug, handlin, insurance, image, stock, ...           []
# 45207  [istock, stock, photography, image, portrait, ...           []
# 47385  [empress, restaurant, restaurant, drinking, br...           []
# 57302  [parent, only, child, parenting, family, infan...           []
# 61780  [public, relation, photo, caption, conversatio...           []
# 67092  [liberia, kalashnikov, rifle, child, in, the, ...           []
# 69125  [car, the, law, office, of, erica, rodriguez, ...           []
# 69804  [cartoon, illustration, getty, image, image, s...           []
# 84910  [photography, portrait, photographer, image, v...           []
# 89621  [stock, photography, photo, caption, photograp...           []
# 97058  [stock, photography, photograph, getty, image,...           []
#
#          pred_label
# 3128   Unidentified
# 7236   Unidentified
# 13875  Unidentified
# 20738  Unidentified
# 21674  Unidentified
# 23910  Unidentified
# 24783  Unidentified
# 25984  Unidentified
# 28735  Unidentified
# 34872  Unidentified
# 37180  Unidentified
# 45207  Unidentified
# 47385  Unidentified
# 57302  Unidentified
# 61780  Unidentified
# 67092  Unidentified
# 69125  Unidentified
# 69804  Unidentified
# 84910  Unidentified
# 89621  Unidentified
# 97058  Unidentified

# %% [markdown]
# ## 4.2 Race Analysis - Test

# %%
val_race_df = hateful_df[hateful_df['gold_pc'].apply(lambda x: 'race' in x)]
val_race_df.shape
# Out:
# (78, 14)

# %%
val_race_df['manual_label'] = val_race_df.apply(lambda x: get_specific_label(x, 'race'), axis=1)
val_race_df['manual_label'] = val_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
val_race_df.head()
# Out:
# <ipython-input-88-16fdcb2fd75a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['manual_label'] = val_race_df.apply(lambda x: get_specific_label(x, 'race'), axis=1)
# <ipython-input-88-16fdcb2fd75a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['manual_label'] = val_race_df['manual_label'].apply(lambda x: x[0: x.index("(")].strip() if "(" in x else x)
#                 img                                               text  \
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
# 1796  img/01796.png       life hack #23 how to get stoned with no weed
# 1925  img/01925.png      i am not racist i just don't like brown sugar
# 2478  img/02478.png              must..resist...urge to.. kill whitey.
# 2568  img/02568.png  whatsthe difference between heroin and i? cops...
#
#      gold_hate                gold_pc                        gold_attack  \
# 1765   hateful            [race, sex]                [inciting_violence]
# 1796   hateful  [race, religion, sex]                [inciting_violence]
# 1925   hateful                 [race]                         [contempt]
# 2478   hateful                 [race]                [inciting_violence]
# 2568   hateful                 [race]  [inciting_violence, dehumanizing]
#
#       best_guess_labels                                           entities  \
# 1765             poster  [Stock photography, , Getty Images, Image, Pho...
# 1796         photograph  [Photograph, Hug, Photo caption, Product, Frie...
# 1925        Scholarship  [Amelia Lost: The Life and Disappearance of Am...
# 2478           official  [Marcus Antonius, Public speaking, Public Rela...
# 2568  man middle finger  [Stock photography, Middle finger, Image, , Ph...
#
#                                         gender  \
# 1765                              [Male, Male]
# 1796  [Female, Female, Female, Female, Female]
# 1925                  [Female, Female, Female]
# 2478                  [Male, Male, Male, Male]
# 2568                                    [Male]
#
#                                                    race manual_label  \
# 1765                                     [Black, Black]        black
# 1796  [Southeast Asian, Southeast Asian, Southeast A...  middle east
# 1925                           [Indian, Indian, Indian]  middle east
# 2478  [White, Latino_Hispanic, Latino_Hispanic, Lati...        black
# 2568                                            [Black]        black
#
#        difficulty_level                                       text_cleaned  \
# 1765     context_medium  [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796  context_difficult  [life, hack, #, 23, how, to, get, stoned, with...
# 1925          text_easy  [i, am, not, racist, i, just, do, not, like, b...
# 2478     context_medium           [mustresist, , urge, to, kill, whitey, ]
# 2568     context_medium  [whatsthe, difference, between, heroin, and, i...
#
#      best_guess_labels_cleaned  \
# 1765                  [poster]
# 1796              [photograph]
# 1925             [scholarship]
# 2478                [official]
# 2568     [man, middle, finger]
#
#                                        entities_cleaned
# 1765  [stock, photography, getty, image, image, phot...
# 1796  [photograph, hug, photo, caption, product, fri...
# 1925  [amelia, lost, , the, life, and, disappearance...
# 2478  [marcus, antonius, public, speaking, public, r...
# 2568  [stock, photography, middle, finger, image, ph...

# %%
val_race_df['manual_label'].value_counts()
# Out:
# black              42
# white              11
# middle east         9
# ???                 8
# hispanic/latino     4
# white or black      1
# german              1
# asia                1
# east asian          1
# Name: manual_label, dtype: int64

# %%
val_race_df['text_cat'] = val_race_df['text_cleaned'].apply(assign_race)
val_race_df['entities_cat'] = val_race_df['entities_cleaned'].apply(assign_race)
val_race_df['best_guess_cat'] = val_race_df['best_guess_labels_cleaned'].apply(assign_race)

val_race_df['combined_cat'] = val_race_df['text_cat'] + val_race_df['entities_cat'] + val_race_df['best_guess_cat']
# Out:
# <ipython-input-90-743d17375c1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['text_cat'] = val_race_df['text_cleaned'].apply(assign_race)
# <ipython-input-90-743d17375c1d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['entities_cat'] = val_race_df['entities_cleaned'].apply(assign_race)
# <ipython-input-90-743d17375c1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['best_guess_cat'] = val_race_df['best_guess_labels_cleaned'].apply(assign_race)
# <ipython-input-90-743d17375c1d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['combined_cat'] = val_race_df['text_cat'] + val_race_df['entities_cat'] + val_race_df['best_guess_cat']

# %%
val_race_df['pred_label'] = val_race_df['combined_cat'].apply(predict_race)
# val_race_df.drop(columns=['text_cat', 'entities_cat', 'best_guess_cat', 'gender', 'race'], inplace=True)
val_race_df.head()
# Out:
# <ipython-input-91-4535ab983a84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_race_df['pred_label'] = val_race_df['combined_cat'].apply(predict_race)
#                 img                                               text  \
# 1765  img/01765.png  after a girl dies, what organ in her body stay...
# 1796  img/01796.png       life hack #23 how to get stoned with no weed
# 1925  img/01925.png      i am not racist i just don't like brown sugar
# 2478  img/02478.png              must..resist...urge to.. kill whitey.
# 2568  img/02568.png  whatsthe difference between heroin and i? cops...
#
#      gold_hate                gold_pc                        gold_attack  \
# 1765   hateful            [race, sex]                [inciting_violence]
# 1796   hateful  [race, religion, sex]                [inciting_violence]
# 1925   hateful                 [race]                         [contempt]
# 2478   hateful                 [race]                [inciting_violence]
# 2568   hateful                 [race]  [inciting_violence, dehumanizing]
#
#       best_guess_labels                                           entities  \
# 1765             poster  [Stock photography, , Getty Images, Image, Pho...
# 1796         photograph  [Photograph, Hug, Photo caption, Product, Frie...
# 1925        Scholarship  [Amelia Lost: The Life and Disappearance of Am...
# 2478           official  [Marcus Antonius, Public speaking, Public Rela...
# 2568  man middle finger  [Stock photography, Middle finger, Image, , Ph...
#
#                                         gender  \
# 1765                              [Male, Male]
# 1796  [Female, Female, Female, Female, Female]
# 1925                  [Female, Female, Female]
# 2478                  [Male, Male, Male, Male]
# 2568                                    [Male]
#
#                                                    race manual_label  \
# 1765                                     [Black, Black]        black
# 1796  [Southeast Asian, Southeast Asian, Southeast A...  middle east
# 1925                           [Indian, Indian, Indian]  middle east
# 2478  [White, Latino_Hispanic, Latino_Hispanic, Lati...        black
# 2568                                            [Black]        black
#
#        difficulty_level                                       text_cleaned  \
# 1765     context_medium  [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796  context_difficult  [life, hack, #, 23, how, to, get, stoned, with...
# 1925          text_easy  [i, am, not, racist, i, just, do, not, like, b...
# 2478     context_medium           [mustresist, , urge, to, kill, whitey, ]
# 2568     context_medium  [whatsthe, difference, between, heroin, and, i...
#
#      best_guess_labels_cleaned  \
# 1765                  [poster]
# 1796              [photograph]
# 1925             [scholarship]
# 2478                [official]
# 2568     [man, middle, finger]
#
#                                        entities_cleaned     text_cat  \
# 1765  [stock, photography, getty, image, image, phot...           []
# 1796  [photograph, hug, photo, caption, product, fri...           []
# 1925  [amelia, lost, , the, life, and, disappearance...  [east asia]
# 2478  [marcus, antonius, public, speaking, public, r...      [white]
# 2568  [stock, photography, middle, finger, image, ph...           []
#
#      entities_cat best_guess_cat combined_cat    pred_label
# 1765           []             []           []  Unidentified
# 1796           []             []           []  Unidentified
# 1925           []             []  [east asia]     east asia
# 2478           []             []      [white]         white
# 2568           []             []           []  Unidentified

# %%
print(val_race_df[(val_race_df['combined_cat'].apply(len) != 0) & (val_race_df['manual_label'] != '???')].shape)
print(val_race_df[(val_race_df['combined_cat'].apply(len) == 0) & (val_race_df['manual_label'] != '???')].shape)
# Out:
# (35, 19)
# (35, 19)

# %%
print(val_race_df[(val_race_df['pred_label'] == val_race_df['manual_label']) & (val_race_df['manual_label'] != '???')].shape)
print(val_race_df[(val_race_df['pred_label'] != val_race_df['manual_label']) & (val_race_df['manual_label'] != '???')].shape)
# Out:
# (24, 19)
# (46, 19)

# %%
mislabel_df = val_race_df[(val_race_df['pred_label'] != val_race_df['manual_label']) & (val_race_df['pred_label'] != 'Unidentified') & (val_race_df['manual_label'] != '???')]
print(mislabel_df.shape)
mislabel_df
# Out:
# (11, 19)
#                  img                                               text  \
# 1925   img/01925.png      i am not racist i just don't like brown sugar
# 2478   img/02478.png              must..resist...urge to.. kill whitey.
# 3745   img/03745.png  your order comes to $37.50 and your white priv...
# 8291   img/08291.png              white people is this a shooting range
# 19508  img/19508.png  the definition of utter disgust in plain black...
# 28190  img/28190.png              when finishing a race is your passion
# 48296  img/48296.png  when you date an asian boy and you trynna get ...
# 49826  img/49826.png  white people on cinco de mayo vs. every other day
# 58672  img/58672.png  did you know that the chinese eat dogs savages...
# 73601  img/73601.png       when you are white and stole your first bike
# 83946  img/83946.png  when a white kid shoots up the school the same...
#
#       gold_hate              gold_pc               gold_attack  \
# 1925    hateful               [race]                [contempt]
# 2478    hateful               [race]       [inciting_violence]
# 3745    hateful               [race]             [inferiority]
# 8291    hateful               [race]            [dehumanizing]
# 19508   hateful               [race]                [contempt]
# 28190   hateful     [religion, race]                 [mocking]
# 48296   hateful          [sex, race]             [inferiority]
# 49826   hateful               [race]             [inferiority]
# 58672   hateful  [nationality, race]  [dehumanizing, contempt]
# 73601   hateful               [race]            [dehumanizing]
# 83946   hateful     [race, religion]            [dehumanizing]
#
#            best_guess_labels  \
# 1925             Scholarship
# 2478                official
# 3745                    desk
# 8291        transgender kids
# 19508                    man
# 28190  rome berlin axis 1936
# 48296          photo caption
# 49826                    art
# 58672                   dish
# 73601                   hand
# 83946                Therapy
#
#                                                 entities  \
# 1925   [Amelia Lost: The Life and Disappearance of Am...
# 2478   [Marcus Antonius, Public speaking, Public Rela...
# 3745   [Furniture, Desk, Media, electronic machine, E...
# 8291   [Jean Piaget, , Family, Infant, Object permane...
# 19508  [Black and white, Thorax, Romance, Photo capti...
# 28190  [Benito Mussolini, World War II, The dark vall...
# 48296  [Mammal, Human behavior, Hug, Human, Happiness...
# 49826  [Stock photography, , Getty Images, Image, Pho...
# 58672  [Charles, Prince of Wales, Camilla, Duchess of...
# 73601  [Hand, Stock photography, Image, stock.xchng, ...
# 83946  [Migraine, Therapy, Headache, Triptan, Health,...
#
#                                                gender  \
# 1925                         [Female, Female, Female]
# 2478                         [Male, Male, Male, Male]
# 3745                         [Female, Female, Female]
# 8291                               [Male, Male, Male]
# 19508                                [Female, Female]
# 28190                                    [Male, Male]
# 48296                        [Female, Female, Female]
# 49826                                    [Male, Male]
# 58672  [Male, Female, Male, Male, Male, Male, Female]
# 73601                                              []
# 83946                                [Female, Female]
#
#                                                     race     manual_label  \
# 1925                            [Indian, Indian, Indian]      middle east
# 2478   [White, Latino_Hispanic, Latino_Hispanic, Lati...            black
# 3745                               [White, White, White]            black
# 8291                               [Black, Black, Black]            black
# 19508                   [Middle Eastern, Middle Eastern]   white or black
# 28190                            [White, Middle Eastern]      middle east
# 48296                              [Black, Black, Black]             asia
# 49826                                     [White, White]  hispanic/latino
# 58672  [White, White, White, Middle Eastern, White, I...       east asian
# 73601                                                 []            black
# 83946                 [Latino_Hispanic, Latino_Hispanic]      middle east
#
#       difficulty_level                                       text_cleaned  \
# 1925         text_easy  [i, am, not, racist, i, just, do, not, like, b...
# 2478    context_medium           [mustresist, , urge, to, kill, whitey, ]
# 3745         text_easy  [your, order, come, to, $, 3750, and, your, wh...
# 8291    context_medium      [white, people, is, this, a, shooting, range]
# 19508   context_medium  [the, definition, of, utter, disgust, in, plai...
# 28190   context_medium      [when, finishing, a, race, is, your, passion]
# 48296                   [when, you, date, an, asian, boy, and, you, tr...
# 49826   knowledge_hard  [white, people, on, cinco, de, mayo, vs, every...
# 58672        text_easy  [did, you, know, that, the, chinese, eat, dog,...
# 73601   context_medium  [when, you, are, white, and, stole, your, firs...
# 83946   context_medium  [when, a, white, kid, shoot, up, the, school, ...
#
#         best_guess_labels_cleaned  \
# 1925                [scholarship]
# 2478                   [official]
# 3745                       [desk]
# 8291           [transgender, kid]
# 19508                       [man]
# 28190  [rome, berlin, axis, 1936]
# 48296            [photo, caption]
# 49826                       [art]
# 58672                      [dish]
# 73601                      [hand]
# 83946                   [therapy]
#
#                                         entities_cleaned        text_cat  \
# 1925   [amelia, lost, , the, life, and, disappearance...     [east asia]
# 2478   [marcus, antonius, public, speaking, public, r...         [white]
# 3745   [furniture, desk, medium, electronic, machine,...         [white]
# 8291   [jean, piaget, family, infant, object, permane...         [white]
# 19508  [black, and, white, thorax, romance, photo, ca...  [black, white]
# 28190  [benito, mussolini, world, war, ii, the, dark,...              []
# 48296  [mammal, human, behavior, hug, human, happines...     [east asia]
# 49826  [stock, photography, getty, image, image, phot...         [white]
# 58672  [charles, ,, prince, of, wale, camilla, ,, duc...     [east asia]
# 73601  [hand, stock, photography, image, stockxchng, ...         [white]
# 83946  [migraine, therapy, headache, triptan, health,...         [white]
#
#          entities_cat best_guess_cat                  combined_cat pred_label
# 1925               []             []                   [east asia]  east asia
# 2478               []             []                       [white]      white
# 3745               []             []                       [white]      white
# 8291               []             []                       [white]      white
# 19508  [black, white]             []  [black, white, black, white]      Mixed
# 28190         [black]             []                       [black]      black
# 48296              []             []                   [east asia]  east asia
# 49826              []             []                       [white]      white
# 58672              []             []                   [east asia]  east asia
# 73601  [black, white]             []         [white, black, white]      white
# 83946              []             []                       [white]      white

# %%
unlabel_df = val_race_df[(val_race_df['pred_label'] != val_race_df['manual_label']) & (val_race_df['pred_label'] == 'Unidentified') & (val_race_df['manual_label'] != '???')]
print(unlabel_df.shape)
unlabel_df
# Out:
# (35, 19)
#                  img                                               text  \
# 1765   img/01765.png  after a girl dies, what organ in her body stay...
# 1796   img/01796.png       life hack #23 how to get stoned with no weed
# 2568   img/02568.png  whatsthe difference between heroin and i? cops...
# 2783   img/02783.png  a picture of my great great great grand grandf...
# 7429   img/07429.png  i'm about to have my 5th abortion fuck you bat...
# 10362  img/10362.png  german british danish austrian diversity. appa...
# 10785  img/10785.png           time to put the "panic" back in hispanic
# 16354  img/16354.png  we've taken this country! now fuck off! we're ...
# 17682  img/17682.png          give them what they deserve kill them all
# 18547  img/18547.png  1st day of 4th grade sandy hook elementary school
# 19730  img/19730.png                jamal is practicing for class sport
# 24316  img/24316.png  sharks don't attack him why? they think it's w...
# 26943  img/26943.png                my incesters built this country!!!!
# 30148  img/30148.png                you mean i don't have to pick it?!?
# 31208  img/31208.png  maybe if we weren't consistent sources of crim...
# 32568  img/32568.png  america taught us how to be happy slaves the s...
# 49650  img/49650.png           and then i asked mom, what's for dinner?
# 50317  img/50317.png  what in the hell is wrong with america voting ...
# 52603  img/52603.png  feeling kinda cute might steal your shit later...
# 53046  img/53046.png  you've heard of elf on a shelf, now get ready for
# 53968  img/53968.png  when you have an 80 point iq but it's the high...
# 56207  img/56207.png  we broke up but she said we could still be cou...
# 56241  img/56241.png  94% of them test positive for rh blood type wh...
# 63280  img/63280.png  so you're never going to forgive the germans b...
# 69548  img/69548.png  wait, mohammad come back i didn't mean to laug...
# 83745  img/83745.png  it is time.. to send these parasites back to t...
# 86170  img/86170.png                         how to keep the thefts out
# 89071  img/89071.png  they don't wash their ass with water and they ...
# 89362  img/89362.png             has extra chromosome probably stole it
# 89425  img/89425.png       hello chocolate paradise princess i'm albert
# 91756  img/91756.png                                 abnormal vs normal
# 92738  img/92738.png  they are the best in basketball because they c...
# 95830  img/95830.png                            face of terrorism in us
# 96180  img/96180.png                           putting bows on your pet
# 98701  img/98701.png                        oh no i can't steal anymore
#
#       gold_hate                gold_pc                        gold_attack  \
# 1765    hateful            [race, sex]                [inciting_violence]
# 1796    hateful  [race, religion, sex]                [inciting_violence]
# 2568    hateful                 [race]  [inciting_violence, dehumanizing]
# 2783    hateful                 [race]            [dehumanizing, mocking]
# 7429    hateful                 [race]                     [dehumanizing]
# 10362   hateful                 [race]                      [inferiority]
# 10785   hateful                 [race]                [inciting_violence]
# 16354   hateful       [religion, race]      [inciting_violence, contempt]
# 17682   hateful                 [race]                [inciting_violence]
# 18547   hateful                 [race]                     [dehumanizing]
# 19730   hateful       [race, religion]                     [dehumanizing]
# 24316   hateful                 [race]                     [dehumanizing]
# 26943   hateful                 [race]                      [inferiority]
# 30148   hateful                 [race]                          [mocking]
# 31208   hateful                 [race]                     [dehumanizing]
# 32568   hateful                 [race]                          [mocking]
# 49650   hateful                 [race]                     [attack_empty]
# 50317   hateful    [race, nationality]                            [slurs]
# 52603   hateful                 [race]        [dehumanizing, inferiority]
# 53046   hateful                 [race]                            [slurs]
# 53968   hateful                 [race]                      [inferiority]
# 56207   hateful                 [race]                     [dehumanizing]
# 56241   hateful                 [race]                     [dehumanizing]
# 63280   hateful       [race, religion]                          [mocking]
# 69548   hateful       [race, religion]                     [dehumanizing]
# 83745   hateful                 [race]                     [dehumanizing]
# 86170   hateful                 [race]                     [dehumanizing]
# 89071   hateful                 [race]                      [inferiority]
# 89362   hateful     [race, disability]        [dehumanizing, inferiority]
# 89425   hateful                 [race]                     [dehumanizing]
# 91756   hateful       [race, religion]        [dehumanizing, inferiority]
# 92738   hateful                 [race]                     [dehumanizing]
# 95830   hateful                 [race]                     [dehumanizing]
# 96180   hateful                 [race]                     [dehumanizing]
# 98701   hateful                 [race]                     [dehumanizing]
#
#                       best_guess_labels  \
# 1765                             poster
# 1796                         photograph
# 2568                  man middle finger
# 2783                               tree
# 7429                   pregnant stomach
# 10362                        friendship
# 10785                         trump gun
# 16354                             beard
# 17682                            player
# 18547                               gun
# 19730                               gun
# 24316                     photo caption
# 26943                     photo caption
# 30148                     photo caption
# 31208                     photo caption
# 32568                         jamiefoxx
# 49650                     photo caption
# 50317                     photo caption
# 52603                           vehicle
# 53046                   winnie the pooh
# 53968                  albinos africain
# 56207                     photo caption
# 56241           retirement plans family
# 63280                      sitting bull
# 69548                              goat
# 83745
# 86170  remove blackheads google vs bing
# 89071           retirement plans family
# 89362                     photo caption
# 89425            man checking out woman
# 91756                        photograph
# 92738                       sport venue
# 95830                             beard
# 96180                               cat
# 98701     inner knee pain after running
#
#                                                 entities  \
# 1765   [Stock photography, , Getty Images, Image, Pho...
# 1796   [Photograph, Hug, Photo caption, Product, Frie...
# 2568   [Stock photography, Middle finger, Image, , Ph...
# 2783   [Illustration, , Clip art, , Getty Images, Ama...
# 7429   [Pregnancy, Abdomen, Health, Stomach, Diastasi...
# 10362  [, Indonesia, , Photograph, Stock photography,...
# 10785  [Gun, Mass shooting, President of the United S...
# 16354  [Beard, Facial hair, Poster, Dude, Photo capti...
# 17682  [, , Sports equipment, Ball, Activewear, Playe...
# 18547  [Gun, Gun, , Getty Images, Image, Stock photog...
# 19730   [Syria, Favela, , Lebanon, , , Gun, , Toy gun, ]
# 24316  [Product, Forehead, Photo caption, Font, Dude,...
# 26943  [Redneck, Facial hair, Mullet, Hillbilly, , Im...
# 30148  [Stock photography, , Getty Images, Photograph...
# 31208  [Stock photography, , Image, Getty Images, Pho...
# 32568  [Jamie Foxx, Kanye West, Django Unchained, Act...
# 49650  [Photograph, Image, Stock photography, How to ...
# 50317  [, Image, Photograph, Stock photography, Getty...
# 52603  [Stock photography, Image, iStock, , Photograp...
# 53046  [, , Actor, Image, Photograph, Stock photograp...
# 53968  [Yagazie Emezi, Getty Images, , Stock photogra...
# 56207  [Royalty-free, Photography, Image, Illustratio...
# 56241  [Pension, Individual retirement account, Retir...
# 63280  [Battle of the Little Bighorn, American Indian...
# 69548  [, Goat, Dog breed, Dog, Photo caption, Snout,...
# 83745  [, Getty Images, iStock, Stock photography, Ph...
# 86170  [Ku Klux Klan, National Public Radio, , United...
# 89071  [Pension, Retirement, Individual retirement ac...
# 89362  [Stock photography, Image, Photograph, Alamy, ...
# 89425  [, Stock photography, stock.xchng, Image, iSto...
# 91756  [Photograph, Jacket, Jeans, Street, Winter, Pr...
# 92738  [Getty Images, , Stock photography, Basketball...
# 95830  [Beard, America's Er Medical Centers, head hai...
# 96180  [Stock photography, Persian cat, Getty Images,...
# 98701  [Knee Pain, Chondromalacia patellae, Patellofe...
#
#                                                   gender  \
# 1765                                        [Male, Male]
# 1796            [Female, Female, Female, Female, Female]
# 2568                                              [Male]
# 2783                                  [Male, Male, Male]
# 7429                                    [Female, Female]
# 10362  [Female, Female, Female, Male, Female, Female,...
# 10785                                       [Male, Male]
# 16354                           [Male, Male, Male, Male]
# 17682                                       [Male, Male]
# 18547                                       [Male, Male]
# 19730                                       [Male, Male]
# 24316                                 [Male, Male, Male]
# 26943                                 [Male, Male, Male]
# 30148                           [Female, Female, Female]
# 31208                                             [Male]
# 32568                           [Male, Male, Male, Male]
# 49650                                       [Male, Male]
# 50317                                             [Male]
# 52603                                     [Male, Female]
# 53046                                 [Male, Male, Male]
# 53968                                   [Female, Female]
# 56207                                       [Male, Male]
# 56241  [Male, Male, Female, Male, Female, Female, Fem...
# 63280                                           [Female]
# 69548                                                 []
# 83745                                                 []
# 86170                                                 []
# 89071  [Male, Male, Male, Male, Female, Female, Femal...
# 89362                                 [Male, Male, Male]
# 89425                           [Male, Male, Male, Male]
# 91756                                   [Female, Female]
# 92738                                                 []
# 95830                                             [Male]
# 96180                             [Female, Female, Male]
# 98701                                                 []
#
#                                                     race     manual_label  \
# 1765                                      [Black, Black]            black
# 1796   [Southeast Asian, Southeast Asian, Southeast A...      middle east
# 2568                                             [Black]            black
# 2783                            [Indian, Indian, Indian]            black
# 7429                  [Latino_Hispanic, Latino_Hispanic]            black
# 10362  [East Asian, Indian, Middle Eastern, White, Bl...      middle east
# 10785                                     [White, White]  hispanic/latino
# 16354     [White, Middle Eastern, Middle Eastern, Black]      middle east
# 17682                   [Middle Eastern, Middle Eastern]            black
# 18547                                     [White, White]            white
# 19730                                     [White, White]      middle east
# 24316                              [Black, Black, Black]            black
# 26943                              [White, White, White]            white
# 30148  [Latino_Hispanic, Latino_Hispanic, Latino_Hisp...            black
# 31208                                            [Black]            black
# 32568                       [Black, White, Black, White]            black
# 49650                                     [Black, Black]            black
# 50317                                            [White]            black
# 52603                                [Black, East Asian]            black
# 53046                    [Southeast Asian, Black, Black]            black
# 53968                                     [White, White]            white
# 56207                                     [White, White]            white
# 56241  [White, White, White, Black, Indian, White, Wh...  hispanic/latino
# 63280                                   [Middle Eastern]           german
# 69548                                                 []            black
# 83745                                                 []      middle east
# 86170                                                 []      middle east
# 89071  [White, White, White, Southeast Asian, Indian,...  hispanic/latino
# 89362  [Latino_Hispanic, Latino_Hispanic, Latino_Hisp...            black
# 89425                  [East Asian, White, White, White]            black
# 91756                               [East Asian, Indian]            black
# 92738                                                 []            black
# 95830                                            [White]            white
# 96180                              [Black, Black, White]            black
# 98701                                                 []            black
#
#                      difficulty_level  \
# 1765                   context_medium
# 1796                context_difficult
# 2568                   context_medium
# 2783                   context_medium
# 7429                   context_medium
# 10362        text_easy&context_medium
# 10785                   context_medum
# 16354                  context_medium
# 17682                  context_medium
# 18547                  knowledge_hard
# 19730                  context_medium
# 24316                  context_medium
# 26943  context_medium& knowledge_hard
# 30148                  context_medium
# 31208                  context_medium
# 32568                  context_medium
# 49650                  context_medium
# 50317                       text_easy
# 52603                  context_medium
# 53046                  context_medium
# 53968                  context_medium
# 56207  context_medium& knowledge_hard
# 56241  context_medium& knowledge_hard
# 63280
# 69548                  context_medium
# 83745                  knowledge_hard
# 86170                  knowledge_hard
# 89071                  context_medium
# 89362                  context_medium
# 89425                  context_medium
# 91756                  context_medium
# 92738                  context_medium
# 95830                  context_medium
# 96180                  context_medium
# 98701                  context_medium
#
#                                             text_cleaned  \
# 1765   [after, a, girl, dy, ,, what, organ, in, her, ...
# 1796   [life, hack, #, 23, how, to, get, stoned, with...
# 2568   [whatsthe, difference, between, heroin, and, i...
# 2783   [a, picture, of, my, great, great, great, gran...
# 7429   [i, am, about, to, have, my, 5th, abortion, fu...
# 10362  [german, british, danish, austrian, diversity,...
# 10785    [time, to, put, the, panic, back, in, hispanic]
# 16354  [we, have, taken, this, country, , now, fuck, ...
# 17682  [give, them, what, they, deserve, kill, them, ...
# 18547  [1st, day, of, 4th, grade, sandy, hook, elemen...
# 19730         [jamal, is, practicing, for, class, sport]
# 24316  [shark, do, not, attack, him, why, , they, thi...
# 26943      [my, incesters, built, this, country, , , , ]
# 30148  [you, mean, i, do, not, have, to, pick, it, , , ]
# 31208  [maybe, if, we, were, not, consistent, source,...
# 32568  [america, taught, u, how, to, be, happy, slave...
# 49650  [and, then, i, asked, mom, ,, what, is, for, d...
# 50317  [what, in, the, hell, is, wrong, with, america...
# 52603  [feeling, kind, of, cute, might, steal, your, ...
# 53046  [you, have, heard, of, elf, on, a, shelf, ,, n...
# 53968  [when, you, have, an, 80, point, iq, but, it, ...
# 56207  [we, broke, up, but, she, said, we, could, sti...
# 56241  [94, %, of, them, test, positive, for, rh, blo...
# 63280  [so, you, are, never, going, to, forgive, the,...
# 69548  [wait, ,, mohammad, come, back, i, did, not, m...
# 83745  [it, is, time, to, send, these, parasite, back...
# 86170                   [how, to, keep, the, theft, out]
# 89071  [they, do, not, wash, their, as, with, water, ...
# 89362       [ha, extra, chromosome, probably, stole, it]
# 89425  [hello, chocolate, paradise, princess, i, am, ...
# 91756                              [abnormal, v, normal]
# 92738  [they, are, the, best, in, basketball, because...
# 95830                       [face, of, terrorism, in, u]
# 96180                      [putting, bow, on, your, pet]
# 98701              [oh, no, i, can, not, steal, anymore]
#
#                   best_guess_labels_cleaned  \
# 1765                               [poster]
# 1796                           [photograph]
# 2568                  [man, middle, finger]
# 2783                                 [tree]
# 7429                    [pregnant, stomach]
# 10362                          [friendship]
# 10785                          [trump, gun]
# 16354                               [beard]
# 17682                              [player]
# 18547                                 [gun]
# 19730                                 [gun]
# 24316                      [photo, caption]
# 26943                      [photo, caption]
# 30148                      [photo, caption]
# 31208                      [photo, caption]
# 32568                           [jamiefoxx]
# 49650                      [photo, caption]
# 50317                      [photo, caption]
# 52603                             [vehicle]
# 53046                   [winnie, the, pooh]
# 53968                    [albino, africain]
# 56207                      [photo, caption]
# 56241            [retirement, plan, family]
# 63280                       [sitting, bull]
# 69548                                [goat]
# 83745                                    []
# 86170  [remove, blackhead, google, v, bing]
# 89071            [retirement, plan, family]
# 89362                      [photo, caption]
# 89425           [man, checking, out, woman]
# 91756                          [photograph]
# 92738                        [sport, venue]
# 95830                               [beard]
# 96180                                 [cat]
# 98701   [inner, knee, pain, after, running]
#
#                                         entities_cleaned text_cat  \
# 1765   [stock, photography, getty, image, image, phot...       []
# 1796   [photograph, hug, photo, caption, product, fri...       []
# 2568   [stock, photography, middle, finger, image, ph...       []
# 2783   [illustration, clip, art, getty, image, amazon...       []
# 7429   [pregnancy, abdomen, health, stomach, diastasi...       []
# 10362  [indonesia, photograph, stock, photography, ge...       []
# 10785  [gun, mass, shooting, president, of, the, unit...       []
# 16354  [beard, facial, hair, poster, dude, photo, cap...       []
# 17682  [sport, equipment, ball, activewear, player, p...       []
# 18547  [gun, gun, getty, image, image, stock, photogr...       []
# 19730            [syria, favela, lebanon, gun, toy, gun]       []
# 24316  [product, forehead, photo, caption, font, dude...       []
# 26943  [redneck, facial, hair, mullet, hillbilly, ima...       []
# 30148  [stock, photography, getty, image, photograph,...       []
# 31208  [stock, photography, image, getty, image, phot...       []
# 32568  [jamie, foxx, kanye, west, django, unchained, ...       []
# 49650  [photograph, image, stock, photography, how, t...       []
# 50317  [image, photograph, stock, photography, getty,...       []
# 52603  [stock, photography, image, istock, photograph...       []
# 53046  [actor, image, photograph, stock, photography,...       []
# 53968  [yagazie, emezi, getty, image, stock, photogra...       []
# 56207  [royalty-free, photography, image, illustratio...       []
# 56241  [pension, individual, retirement, account, ret...       []
# 63280  [battle, of, the, little, bighorn, american, i...       []
# 69548  [goat, dog, breed, dog, photo, caption, snout,...       []
# 83745  [getty, image, istock, stock, photography, pho...       []
# 86170  [ku, klux, klan, national, public, radio, unit...       []
# 89071  [pension, retirement, individual, retirement, ...       []
# 89362  [stock, photography, image, photograph, alamy,...       []
# 89425  [stock, photography, stockxchng, image, istock...       []
# 91756  [photograph, jacket, jean, street, winter, pro...       []
# 92738  [getty, image, stock, photography, basketball,...       []
# 95830  [beard, america, 's, er, medical, center, head...       []
# 96180  [stock, photography, persian, cat, getty, imag...       []
# 98701  [knee, pain, chondromalacia, patella, patellof...       []
#
#       entities_cat best_guess_cat combined_cat    pred_label
# 1765            []             []           []  Unidentified
# 1796            []             []           []  Unidentified
# 2568            []             []           []  Unidentified
# 2783            []             []           []  Unidentified
# 7429            []             []           []  Unidentified
# 10362           []             []           []  Unidentified
# 10785           []             []           []  Unidentified
# 16354           []             []           []  Unidentified
# 17682           []             []           []  Unidentified
# 18547           []             []           []  Unidentified
# 19730           []             []           []  Unidentified
# 24316           []             []           []  Unidentified
# 26943           []             []           []  Unidentified
# 30148           []             []           []  Unidentified
# 31208           []             []           []  Unidentified
# 32568           []             []           []  Unidentified
# 49650           []             []           []  Unidentified
# 50317           []             []           []  Unidentified
# 52603           []             []           []  Unidentified
# 53046           []             []           []  Unidentified
# 53968           []             []           []  Unidentified
# 56207           []             []           []  Unidentified
# 56241           []             []           []  Unidentified
# 63280           []             []           []  Unidentified
# 69548           []             []           []  Unidentified
# 83745           []             []           []  Unidentified
# 86170           []             []           []  Unidentified
# 89071           []             []           []  Unidentified
# 89362           []             []           []  Unidentified
# 89425           []             []           []  Unidentified
# 91756           []             []           []  Unidentified
# 92738           []             []           []  Unidentified
# 95830           []             []           []  Unidentified
# 96180           []             []           []  Unidentified
# 98701           []             []           []  Unidentified

# %% [markdown]
# # 5. Religion Analysis

# %%
categories = (
    ("muslim", ("muslim", "islamic", "islam", "moslem", "hijab", "jihad", "burqa", "abdul")),
    ("jews", ("jew", "nazi", "hitler")),
    ("catholic christian", ("catholic", )),
    ("christian", ("undefinedtobeconfirmed",))
)

special_kws = [
    ("catholic christian", "pedo"),
    ("jews", "jew"),
    ("muslim", "moham")
]

def assign_religion(tokens):
    keywords, labels  = [], []
    for t in tokens:
        for cat, kws in categories:
            if t in kws:
                keywords.append((t, kws))
                labels.append(cat)
    
    sent = " ".join(tokens)
    for cat, special_kw in special_kws:
        if special_kw in sent:
            keywords.append(t)
            labels.append(cat)
    
    return labels

def predict_religion(combined_cat):
    from collections import Counter
    
    if len(combined_cat) == 0:
        return "Unidentified"
    
    counter = Counter(combined_cat)
    elements = counter.most_common(2)
    
    if len(elements) == 1 or elements[0][1] > elements[1][1]:
        return elements[0][0]
    
    return "Mixed"

# %%
train_religion_df['text_cat'] = train_religion_df['text_cleaned'].apply(assign_religion)
train_religion_df['entities_cat'] = train_religion_df['entities_cleaned'].apply(assign_religion)
train_religion_df['best_guess_cat'] = train_religion_df['best_guess_labels_cleaned'].apply(assign_religion)

train_religion_df['combined_cat'] = train_religion_df['text_cat'] + train_religion_df['entities_cat'] + train_religion_df['best_guess_cat']
# Out:
# <ipython-input-113-f6b6138a5996>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['text_cat'] = train_religion_df['text_cleaned'].apply(assign_religion)
# <ipython-input-113-f6b6138a5996>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['entities_cat'] = train_religion_df['entities_cleaned'].apply(assign_religion)
# <ipython-input-113-f6b6138a5996>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['best_guess_cat'] = train_religion_df['best_guess_labels_cleaned'].apply(assign_religion)
# <ipython-input-113-f6b6138a5996>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['combined_cat'] = train_religion_df['text_cat'] + train_religion_df['entities_cat'] + train_religion_df['best_guess_cat']

# %%
train_race_df.head()
# Out:
#                 img                                               text  \
# 2457  img/02457.png  i hate when i see a black out in my neighborho...
# 2719  img/02719.png      your black neighbor after you called the cops
# 3128  img/03128.png                          lazy day nothing to steal
# 3591  img/03591.png  joins the democrat party to indulge in deep se...
# 4859  img/04859.png                arnold schwarzenigger i'll be black
#
#      gold_hate gold_pc     gold_attack best_guess_labels  \
# 2457   hateful  [race]      [contempt]          kkk cool
# 2719   hateful  [race]  [dehumanizing]       bonobo male
# 3128   hateful  [race]  [dehumanizing]             tribe
# 3591   hateful  [race]  [attack_empty]        nerd girls
# 4859   hateful  [race]         [slurs]             beard
#
#                                                entities  \
# 2457  [Ku Klux Klan, Stone Mountain, Loyal White Kni...
# 2719  [Bonobo, Primate, Human, New World monkeys, Te...
# 3128  [Omo River, Hamar people, Tribe, , Arbore peop...
# 3591  [Stock photography, Photograph, Getty Images, ...
# 4859  [T-Shirt, Beard, Product, Brand, Photo caption...
#
#                         gender                   race manual_label  \
# 2457                        []                     []        black
# 2719                        []                     []        black
# 3128        [Male, Male, Male]  [Black, Black, Black]        black
# 3591  [Female, Female, Female]  [White, White, White]        black
# 4859                    [Male]                [Black]        black
#
#                     difficulty_level  \
# 2457                  context_medium
# 2719                  context_medium
# 3128  context_medium& knowledge_hard
# 3591        text_easy&context_medium
# 4859        easy_text&knowledge_hard
#
#                                            text_cleaned  \
# 2457  [i, hate, when, i, see, a, black, out, in, my,...
# 2719  [your, black, neighbor, after, you, called, th...
# 3128                    [lazy, day, nothing, to, steal]
# 3591  [join, the, democrat, party, to, indulge, in, ...
# 4859       [arnold, schwarzenigger, i, will, be, black]
#
#      best_guess_labels_cleaned  \
# 2457               [kkk, cool]
# 2719            [bonobo, male]
# 3128                   [tribe]
# 3591              [nerd, girl]
# 4859                   [beard]
#
#                                        entities_cleaned    combined_cat  \
# 2457  [ku, klux, klan, stone, mountain, loyal, white...  [black, white]
# 2719  [bonobo, primate, human, new, world, monkey, t...         [black]
# 3128  [omo, river, hamar, people, tribe, arbore, peo...              []
# 3591  [stock, photography, photograph, getty, image,...         [black]
# 4859  [t-shirt, beard, product, brand, photo, captio...         [black]
#
#         pred_label
# 2457         Mixed
# 2719         black
# 3128  Unidentified
# 3591         black
# 4859         black

# %%
train_religion_df['pred_label'] = train_religion_df['combined_cat'].apply(predict_religion)
train_religion_df.drop(columns=['text_cat', 'entities_cat', 'best_guess_cat'], inplace=True)
train_religion_df.head()
# Out:
# <ipython-input-115-96e057824813>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_religion_df['pred_label'] = train_religion_df['combined_cat'].apply(predict_religion)
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 img                                               text  \
# 1497  img/01497.png  now back to the married islamic classic.. to c...
# 1579  img/01579.png  muslim figure: "we must have pork-free menus o...
# 2653  img/02653.png  england where moslems can rape your children a...
# 4361  img/04361.png  islam turning every single country it touches ...
# 6541  img/06541.png  hey i just met you and this is crazy, but here...
#
#      gold_hate     gold_pc     gold_attack    best_guess_labels  \
# 1497   hateful  [religion]  [dehumanizing]        photo caption
# 1579   hateful  [religion]     [exclusion]    با حجاب در آمریکا
# 2653   hateful  [religion]  [dehumanizing]  christmas in london
# 4361   hateful  [religion]      [contempt]          summit camp
# 6541   hateful  [religion]       [mocking]            gentleman
#
#                                                entities  \
# 1497  [, Nangalam, Getty Images, Image, Photo captio...
# 1579  [United States, , Islam in the United States, ...
# 2653  [London, Christmas Day, , King's College Chape...
# 4361  [Graphic design, Black and white, Poster, Font...
# 6541  [Black and white, Monochrome, M, Photo caption...
#
#                                                 gender  \
# 1497                                [Male, Male, Male]
# 1579  [Female, Male, Female, Male, Male, Male, Female]
# 2653                                                []
# 4361                                                []
# 6541                                [Male, Male, Male]
#
#                                                    race manual_label  \
# 1497                            [Indian, White, Indian]       muslim
# 1579  [Latino_Hispanic, Black, White, Black, Black, ...       muslim
# 2653                                                 []       muslim
# 4361                                                 []       muslim
# 6541                              [White, White, White]         jews
#
#      difficulty_level                                       text_cleaned  \
# 1497                   [now, back, to, the, married, islamic, classic...
# 1579                   [muslim, figure, , we, must, have, pork-free, ...
# 2653                   [england, where, moslem, can, rape, your, chil...
# 4361                   [islam, turning, every, single, country, it, t...
# 6541                   [hey, i, just, met, you, and, this, is, crazy,...
#
#      best_guess_labels_cleaned  \
# 1497          [photo, caption]
# 1579    [با, حجاب, در, آمریکا]
# 2653   [christmas, in, london]
# 4361            [summit, camp]
# 6541               [gentleman]
#
#                                        entities_cleaned  \
# 1497  [nangalam, getty, image, image, photo, caption...
# 1579  [united, state, islam, in, the, united, state,...
# 2653  [london, christmas, day, king, 's, college, ch...
# 4361  [graphic, design, black, and, white, poster, f...
# 6541  [black, and, white, monochrome, m, photo, capt...
#
#                                   combined_cat    pred_label
# 1497                                  [muslim]        muslim
# 1579  [muslim, muslim, muslim, muslim, muslim]        muslim
# 2653                                  [muslim]        muslim
# 4361                                  [muslim]        muslim
# 6541                                        []  Unidentified

# %%
print(train_religion_df[(train_religion_df['combined_cat'].apply(len) != 0) & (train_religion_df['manual_label'] != '???')].shape)
print(train_religion_df[(train_religion_df['combined_cat'].apply(len) == 0) & (train_religion_df['manual_label'] != '???')].shape)
# Out:
# (73, 16)
# (25, 16)

# %%
print(train_religion_df[(train_religion_df['pred_label'] == train_religion_df['manual_label']) & (train_religion_df['manual_label'] != '???')].shape)
print(train_religion_df[(train_religion_df['pred_label'] != train_religion_df['manual_label']) & (train_religion_df['manual_label'] != '???')].shape)
# Out:
# (70, 16)
# (28, 16)

# %%
mislabel_df = train_religion_df[(train_religion_df['pred_label'] != train_religion_df['manual_label']) & (train_religion_df['pred_label'] != 'Unidentified') & (train_religion_df['manual_label'] != '???')]

print(mislabel_df.shape)
mislabel_df
# Out:
# (3, 16)
#                  img                                               text  \
# 10492  img/10492.png  "judgement day will not come until the muslims...
# 34751  img/34751.png  muslims: screaming about their religion being ...
# 38246  img/38246.png  islamic extremists try to exterminate judaism ...
#
#       gold_hate     gold_pc          gold_attack   best_guess_labels  \
# 10492   hateful  [religion]  [inciting_violence]             glasses
# 34751   hateful  [religion]  [inciting_violence]            shoulder
# 38246   hateful  [religion]            [mocking]  heath ledger joker
#
#                                                 entities  \
# 10492  [Glasses, Photo caption, Stock photography, Ph...
# 34751  [Forehead, Hair coloring, Photo caption, Font,...
# 38246  [Heath Ledger, The Dark Knight, Joker, The Jok...
#
#                          gender  \
# 10492                    [Male]
# 34751  [Female, Female, Female]
# 38246          [Female, Female]
#
#                                                     race     manual_label  \
# 10492                                            [White]  muslim or  jews
# 34751  [Latino_Hispanic, Latino_Hispanic, Latino_Hisp...           muslim
# 38246                 [Southeast Asian, Southeast Asian]           muslim
#
#       difficulty_level                                       text_cleaned  \
# 10492                   [judgement, day, will, not, come, until, the, ...
# 34751                   [muslim, , screaming, about, their, religion, ...
# 38246                   [islamic, extremist, try, to, exterminate, jud...
#
#       best_guess_labels_cleaned  \
# 10492                   [glass]
# 34751                [shoulder]
# 38246    [heath, ledger, joker]
#
#                                         entities_cleaned  \
# 10492  [glass, photo, caption, stock, photography, ph...
# 34751  [forehead, hair, coloring, photo, caption, fon...
# 38246  [heath, ledger, the, dark, knight, joker, the,...
#
#                combined_cat pred_label
# 10492  [muslim, jews, jews]       jews
# 34751  [muslim, jews, jews]       jews
# 38246        [muslim, jews]      Mixed

# %%
unlabel_df = train_religion_df[(train_religion_df['pred_label'] != train_religion_df['manual_label']) & (train_religion_df['pred_label'] == 'Unidentified') & (train_religion_df['manual_label'] != '???')]

print(unlabel_df.shape)
unlabel_df
# Out:
# (25, 16)
#                  img                                               text  \
# 6541   img/06541.png  hey i just met you and this is crazy, but here...
# 8534   img/08534.png  if you don't believe in god you're going to su...
# 13249  img/13249.png  here's a little song i call "the talmudists ar...
# 14087  img/14087.png  so i bent him over like this and i made sure h...
# 15479  img/15479.png  when you're in heaven and you got your 72 virg...
# 23054  img/23054.png  911 was personally difficult for me i lost 19 ...
# 25489  img/25489.png   brother... a day without a blast is a day wasted
# 35684  img/35684.png  when you tell him he can't marry a 6 years old...
# 41092  img/41092.png  ana frank at 14 years old ana frank at 15 year...
# 41270  img/41270.png               adult diapers for complete shitheads
# 46872  img/46872.png         how does he drive his car? he hits the gas
# 48271  img/48271.png  me and the boys after killing innocent people ...
# 48976  img/48976.png  gas stay in if da door "ay, tone. how'd da is ...
# 58127  img/58127.png                  is it a boy or a girl it's a bomb
# 59376  img/59376.png  a head diaper is required when you have shit f...
# 61028  img/61028.png  what's the difference between a cow and the ho...
# 64207  img/64207.png  me and the boys after killing innocent people ...
# 69405  img/69405.png                    storm in they can't rape us all
# 74098  img/74098.png  me: *turns the oven to 450 degrees* everyone e...
# 75234  img/75234.png  she called me islamphobe so i gave her some sh...
# 83921  img/83921.png                  this faceapp stuff is incredible!
# 90278  img/90278.png  when your fifth wife eats grass from another g...
# 92481  img/92481.png  we have 3 apples. we give away 2 apples now ca...
# 94031  img/94031.png          felling cute. might fuck a goat later idk
# 94087  img/94087.png  "never forget" -you said.. i am the proof- you...
#
#       gold_hate     gold_pc          gold_attack  \
# 6541    hateful  [religion]            [mocking]
# 8534    hateful  [religion]        [inferiority]
# 13249   hateful  [religion]       [dehumanizing]
# 14087   hateful  [religion]       [dehumanizing]
# 15479   hateful  [religion]       [dehumanizing]
# 23054   hateful  [religion]       [dehumanizing]
# 25489   hateful  [religion]       [dehumanizing]
# 35684   hateful  [religion]       [dehumanizing]
# 41092   hateful  [religion]            [mocking]
# 41270   hateful  [religion]        [inferiority]
# 46872   hateful  [religion]            [mocking]
# 48271   hateful  [religion]       [dehumanizing]
# 48976   hateful  [religion]            [mocking]
# 58127   hateful  [religion]       [dehumanizing]
# 59376   hateful  [religion]        [inferiority]
# 61028   hateful  [religion]            [mocking]
# 64207   hateful  [religion]       [dehumanizing]
# 69405   hateful  [religion]       [dehumanizing]
# 74098   hateful  [religion]            [mocking]
# 75234   hateful  [religion]  [inciting_violence]
# 83921   hateful  [religion]       [dehumanizing]
# 90278   hateful  [religion]       [dehumanizing]
# 92481   hateful  [religion]       [dehumanizing]
# 94031   hateful  [religion]       [dehumanizing]
# 94087   hateful  [religion]       [dehumanizing]
#
#                    best_guess_labels  \
# 6541                       gentleman
# 8534               estranged parents
# 13249                kermit the frog
# 14087                         person
# 15479                  photo caption
# 23054                           girl
# 25489                  photo caption
# 35684                  photo caption
# 41092                           Soap
# 41270                  photo caption
# 46872                ubermensch meme
# 48271                  saudi friends
# 48976  auschwitz outside gas chamber
# 58127                     friendship
# 59376               ilhan omar tweet
# 61028                          fauna
# 64207                  saudi friends
# 69405                  photo caption
# 74098                  surprised cat
# 75234                        t shirt
# 83921                Osama bin Laden
# 90278                  photo caption
# 92481         monochrome photography
# 94031                  photo caption
# 94087                  photo caption
#
#                                                 entities  \
# 6541   [Black and white, Monochrome, M, Photo caption...
# 8534   [Parent, Family estrangement, Daughter, , Fami...
# 13249  [Kermit the Frog, Miss Piggy, The Muppets, Rai...
# 14087                                    [Photo caption]
# 15479  [Facial hair, Photo caption, Product, Dude, Ha...
# 23054                           [Photo caption, Student]
# 25489              [Moustache M, Photo caption, Product]
# 35684  [Human behavior, Beard, Photo caption, Human, ...
# 41092  [Bar Soap, Soap, Selah Vie Soapery, Oil, Essen...
# 41270  [Photo caption, Headgear, Font, Capital asset ...
# 46872  [Meme, Internet meme, Imgflip, , , , Imgur, , ...
# 48271  [Getty Images, , Stock photography, Image, Pho...
# 48976  [Memorial and Museum Auschwitz I, , Gas chambe...
# 58127  [Pregnancy, Dua, , Adhan, Adab, , Hyperemesis ...
# 59376  [Ilhan Omar, Second impeachment of Donald Trum...
# 61028  [Calf, Goat, Dairy cattle, Dairy, Snout, Photo...
# 64207  [, Getty Images, Stock photography, Image, Pho...
# 69405                    [Photo caption, Laughter, Dude]
# 74098  [Cat, Dog, Bongo Cat, Veterinarian, Meow, Lolc...
# 75234  [Human behavior, Product, T-Shirt, Brand, Logo...
# 83921  [Osama bin Laden, Killing of Osama bin Laden, ...
# 90278  [Facial hair, Photo caption, Product, Dude, Ha...
# 92481  [Myanmar (Burma), Rohingya people, World, Phot...
# 94031  [Image, Stock photography, Getty Images, , iSt...
# 94087                                    [Photo caption]
#
#                                                   gender  \
# 6541                                  [Male, Male, Male]
# 8534                          [Female, Male, Male, Male]
# 13249                                                 []
# 14087                                             [Male]
# 15479               [Male, Male, Male, Male, Male, Male]
# 23054                   [Female, Female, Female, Female]
# 25489                                             [Male]
# 35684                                             [Male]
# 41092                                   [Female, Female]
# 41270                           [Female, Female, Female]
# 46872                                             [Male]
# 48271  [Male, Male, Male, Male, Male, Female, Male, M...
# 48976                                                 []
# 58127                           [Female, Female, Female]
# 59376                                   [Female, Female]
# 61028                                                 []
# 64207  [Male, Male, Male, Male, Male, Female, Male, M...
# 69405                                 [Male, Male, Male]
# 74098                                                 []
# 75234                                       [Male, Male]
# 83921                       [Male, Female, Male, Female]
# 90278               [Male, Male, Male, Male, Male, Male]
# 92481                                             [Male]
# 94031                                             [Male]
# 94087                   [Female, Female, Female, Female]
#
#                                                     race        manual_label  \
# 6541                               [White, White, White]                jews
# 8534                   [East Asian, White, White, White]        christianity
# 13249                                                 []                jews
# 14087                                            [White]  catholic christian
# 15479  [Latino_Hispanic, White, Latino_Hispanic, Whit...              muslim
# 23054           [Middle Eastern, Indian, Indian, Indian]              muslim
# 25489                                   [Middle Eastern]              muslim
# 35684                                   [Middle Eastern]              muslim
# 41092                                     [White, White]                jews
# 41270                              [Black, Black, Black]              muslim
# 46872                                            [White]                jews
# 48271  [Middle Eastern, Middle Eastern, Middle Easter...              muslim
# 48976                                                 []                jews
# 58127            [White, Middle Eastern, Middle Eastern]              muslim
# 59376                                     [Black, Black]              muslim
# 61028                                                 []                jews
# 64207  [Middle Eastern, Middle Eastern, Middle Easter...              muslim
# 69405                              [White, White, White]  catholic christian
# 74098                                                 []                jews
# 75234                   [Middle Eastern, Middle Eastern]              muslim
# 83921                   [Indian, Indian, Indian, Indian]              muslim
# 90278  [Latino_Hispanic, White, Latino_Hispanic, Whit...              muslim
# 92481                                           [Indian]              muslim
# 94031                                            [White]              muslim
# 94087                       [Black, Black, Black, Black]              muslim
#
#       difficulty_level                                       text_cleaned  \
# 6541                    [hey, i, just, met, you, and, this, is, crazy,...
# 8534         easy&hard  [if, you, do, not, believe, in, god, you, are,...
# 13249                   [here, is, a, little, song, i, call, the, talm...
# 14087                   [so, i, bent, him, over, like, this, and, i, m...
# 15479                   [when, you, are, in, heaven, and, you, got, yo...
# 23054                   [911, wa, personally, difficult, for, me, i, l...
# 25489                   [brother, , a, day, without, a, blast, is, a, ...
# 35684                   [when, you, tell, him, he, can, not, marry, a,...
# 41092                   [ana, frank, at, 14, year, old, ana, frank, at...
# 41270                            [adult, diaper, for, complete, shithead]
# 46872                   [how, doe, he, drive, his, car, , he, hit, the...
# 48271                   [me, and, the, boy, after, killing, innocent, ...
# 48976                   [gas, stay, in, if, da, door, ay, ,, tone, , h...
# 58127                      [is, it, a, boy, or, a, girl, it, is, a, bomb]
# 59376                   [a, head, diaper, is, required, when, you, hav...
# 61028                   [what, is, the, difference, between, a, cow, a...
# 64207                   [me, and, the, boy, after, killing, innocent, ...
# 69405             easy          [storm, in, they, can, not, rape, u, all]
# 74098                   [me, , *turns, the, oven, to, 450, degrees*, e...
# 75234                   [she, called, me, islamphobe, so, i, gave, her...
# 83921                            [this, faceapp, stuff, is, incredible, ]
# 90278                   [when, your, fifth, wife, eats, grass, from, a...
# 92481                   [we, have, 3, apple, , we, give, away, 2, appl...
# 94031                   [felling, cute, , might, fuck, a, goat, later,...
# 94087                   [never, forget, -you, said, i, am, the, proof-...
#
#                 best_guess_labels_cleaned  \
# 6541                          [gentleman]
# 8534                  [estranged, parent]
# 13249                 [kermit, the, frog]
# 14087                            [person]
# 15479                    [photo, caption]
# 23054                              [girl]
# 25489                    [photo, caption]
# 35684                    [photo, caption]
# 41092                              [soap]
# 41270                    [photo, caption]
# 46872                  [ubermensch, meme]
# 48271                     [saudi, friend]
# 48976  [auschwitz, outside, gas, chamber]
# 58127                        [friendship]
# 59376                [ilhan, omar, tweet]
# 61028                             [fauna]
# 64207                     [saudi, friend]
# 69405                    [photo, caption]
# 74098                    [surprised, cat]
# 75234                          [t, shirt]
# 83921                 [osama, bin, laden]
# 90278                    [photo, caption]
# 92481           [monochrome, photography]
# 94031                    [photo, caption]
# 94087                    [photo, caption]
#
#                                         entities_cleaned combined_cat  \
# 6541   [black, and, white, monochrome, m, photo, capt...           []
# 8534   [parent, family, estrangement, daughter, famil...           []
# 13249  [kermit, the, frog, miss, piggy, the, muppets,...           []
# 14087                                   [photo, caption]           []
# 15479  [facial, hair, photo, caption, product, dude, ...           []
# 23054                          [photo, caption, student]           []
# 25489            [moustache, m, photo, caption, product]           []
# 35684  [human, behavior, beard, photo, caption, human...           []
# 41092  [bar, soap, soap, selah, vie, soapery, oil, es...           []
# 41270  [photo, caption, headgear, font, capital, asse...           []
# 46872     [meme, internet, meme, imgflip, imgur, humour]           []
# 48271  [getty, image, stock, photography, image, phot...           []
# 48976  [memorial, and, museum, auschwitz, i, gas, cha...           []
# 58127  [pregnancy, dua, adhan, adab, hyperemesis, gra...           []
# 59376  [ilhan, omar, second, impeachment, of, donald,...           []
# 61028  [calf, goat, dairy, cattle, dairy, snout, phot...           []
# 64207  [getty, image, stock, photography, image, phot...           []
# 69405                   [photo, caption, laughter, dude]           []
# 74098  [cat, dog, bongo, cat, veterinarian, meow, lol...           []
# 75234  [human, behavior, product, t-shirt, brand, log...           []
# 83921  [osama, bin, laden, killing, of, osama, bin, l...           []
# 90278  [facial, hair, photo, caption, product, dude, ...           []
# 92481  [myanmar, (, burma, ), rohingya, people, world...           []
# 94031  [image, stock, photography, getty, image, isto...           []
# 94087                                   [photo, caption]           []
#
#          pred_label
# 6541   Unidentified
# 8534   Unidentified
# 13249  Unidentified
# 14087  Unidentified
# 15479  Unidentified
# 23054  Unidentified
# 25489  Unidentified
# 35684  Unidentified
# 41092  Unidentified
# 41270  Unidentified
# 46872  Unidentified
# 48271  Unidentified
# 48976  Unidentified
# 58127  Unidentified
# 59376  Unidentified
# 61028  Unidentified
# 64207  Unidentified
# 69405  Unidentified
# 74098  Unidentified
# 75234  Unidentified
# 83921  Unidentified
# 90278  Unidentified
# 92481  Unidentified
# 94031  Unidentified
# 94087  Unidentified
